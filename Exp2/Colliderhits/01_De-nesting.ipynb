# %%
# Added cell to set Working Directory to your location
import os
import ast
import glob
import numpy as np
import pandas as pd
import json
import time

# %%
path = "/Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller" 

# csv files in the path
files = glob.glob(path + "/*.csv")

for filename in files:
    temp_one_part = pd.read_csv(filename)
    # Drop unnecessary variables
    temp_one_part.drop(["0"],axis=1, inplace=True)
    # Format index column
    temp_one_part.rename(columns = {'Unnamed: 0':'index'}, inplace=True)
    temp_one_part.dropna(subset=['hitPointOnObject'], inplace=True)
    # Given the way our the files have been constructed up to now, the contents of "hitPointOnObject" are not longer read as dictionary.
    # So we go row by row turn them into string and then properly format them into dictionaries to be able to explote that data on the subsequent step.
    temp_one_part["hitPointOnObject"] = [ast.literal_eval(str(row_value)) for row_value in temp_one_part["hitPointOnObject"]]
    # Turn the dictionary values into columns
    temp_one_part = temp_one_part.join(temp_one_part['hitPointOnObject'].apply(pd.Series).add_prefix("hitPointOnObject_"))
    temp_one_part.drop(["hitPointOnObject"], axis=1, inplace= True)
    temp_one_part.to_csv("/Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/02_Individuals_Colliders/" + str(filename[-8:len(filename)]))
    print(str(filename) + " Done")
# Out:
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/1031.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/1268.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/1574.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/1843.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/2069.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/3193.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/3540.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/4580.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/4598.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/4847.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/4875.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/5161.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/5189.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/5743.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/5766.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/5851.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/5972.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/6406.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/7081.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/7393.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/7823.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/7935.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/8629.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/9297.csv Done
# /Volumes/TwoTeras/1_Experiment_2/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/9627.csv Done

# %%
temp_one_part.head()
# Out:
#    index  SubjectID  Session  SessionSubsection  timeStampDataPointStart  \
# 0      0       9627        1                  1             1.667983e+09
# 1      1       9627        1                  1             1.667983e+09
# 3      3       9627        1                  1             1.667983e+09
# 4      4       9627        1                  1             1.667983e+09
# 5      5       9627        1                  1             1.667983e+09
#
#    timeStampDataPointEnd  timeStampGetVerboseData  \
# 0           1.667983e+09             1.667983e+09
# 1           1.667983e+09             1.667983e+09
# 3           1.667983e+09             1.667983e+09
# 4           1.667983e+09             1.667983e+09
# 5           1.667983e+09             1.667983e+09
#
#    combinedGazeValidityBitmask  \
# 0                            3
# 1                            3
# 3                            3
# 4                            3
# 5                            3
#
#                              rayCastHitsCombinedEyes  \
# 0  [{'hitPointOnObject': {'x': -60.83253479003906...
# 1  [{'hitPointOnObject': {'x': -60.83253479003906...
# 3  [{'hitPointOnObject': {'x': -61.2884407043457,...
# 4  [{'hitPointOnObject': {'x': -61.23129653930664...
# 5  [{'hitPointOnObject': {'x': -60.97626876831055...
#
#    eyePositionCombinedWorld.x  ...  bodyTrackerRotation.x  \
# 0                  -59.125370  ...                    0.0
# 1                  -59.125370  ...                    0.0
# 3                  -59.150620  ...                    0.0
# 4                  -59.150589  ...                    0.0
# 5                  -59.154217  ...                    0.0
#
#    bodyTrackerRotation.y  bodyTrackerRotation.z           hitColliderType  \
# 0                    0.0                    0.0  UnityEngine.MeshCollider
# 1                    0.0                    0.0  UnityEngine.MeshCollider
# 3                    0.0                    0.0  UnityEngine.MeshCollider
# 4                    0.0                    0.0  UnityEngine.MeshCollider
# 5                    0.0                    0.0  UnityEngine.MeshCollider
#
#                        hitObjectColliderBoundsCenter  hitObjectColliderName  \
# 0  {'x': -165.37255859375, 'y': -0.46650505065917...          terrain_O.001
# 1  {'x': -165.37255859375, 'y': -0.46650505065917...          terrain_O.001
# 3  {'x': -165.37255859375, 'y': -0.46650505065917...          terrain_O.001
# 4  {'x': -165.37255859375, 'y': -0.46650505065917...          terrain_O.001
# 5  {'x': -165.37255859375, 'y': -0.46650505065917...          terrain_O.001
#
#    ordinalOfHit  hitPointOnObject_x  hitPointOnObject_y  hitPointOnObject_z
# 0           1.0          -60.832535            0.923188           67.663101
# 1           1.0          -60.832535            0.923188           67.663101
# 3           1.0          -61.288441            0.938106           62.720810
# 4           1.0          -61.231297            1.050482           63.631241
# 5           1.0          -60.976269            0.982334           63.192947
#
# [5 rows x 45 columns]
