# %%
import pandas as pd
import numpy as np
import re
import glob
import math
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "/Volumes/SSD/00_Data_Processing/Pre_processed/05_Debbies_gaze" 

  
# csv files in the path
files = glob.glob(path + "/*.csv")
  
# defining an empty list to store 
# content
data_frame = pd.DataFrame()
content = []
  
# checking all the csv files in the 
# specified path
for filename in files:
    
    # reading content of csv file
    # content.append(filename)
    One_participant = pd.read_csv(filename)
    One_participant.drop(columns=['Unnamed: 0', 'level_0','Unnamed: 0.1', 'Unnamed: 0.1.1'], inplace=True)
    print(filename[-10:-4])
    content.append(One_participant)

# converting content to data frame
data_frame = pd.concat(content)
# Out:
# 0479_2
# 0479_3
# 0479_5
# 1754_1
# 1754_2
# 1754_3
# 1754_4
# 1754_5
# 2258_1
# 2258_2
# 2258_3
# 2258_4
# 2258_5
# 2361_2
# 2361_3
# 2361_4
# 2361_5
# 2693_1
# 2693_2
# 2693_3
# 2693_4
# 2693_5
# 3246_1
# 3246_2
# 3246_3
# 3246_5
# 3310_1
# 3310_2
# 3310_3
# 3310_4
# 3310_5
# 3572_1
# 3572_2
# 3572_3
# 3572_4
# 3976_1
# 3976_2
# 3976_3
# 3976_4
# 3976_5
# 4176_1
# 4176_2
# 4176_3
# 4176_4
# 4176_5
# 4796_1
# 4796_2
# 4796_3
# 4796_4
# 4796_5
# 4917_1
# 4917_2
# 4917_3
# 4917_4
# 4917_5
# 5238_1
# 5238_2
# 5238_3
# 5238_4
# 5531_1
# 5531_3
# 5531_4
# 5531_5
# 5741_1
# 5741_2
# 5741_3
# 5741_4
# 5741_5
# 6642_1
# 6642_2
# 6642_3
# 6642_4
# 6642_5
# 7093_1
# 7093_2
# 7093_3
# 7093_4
# 7093_5
# 7264_1
# 7264_2
# 7264_3
# 7264_4
# 7264_5
# 7412_1
# 7412_2
# 7412_3
# 7412_4
# 7412_5
# 7842_1
# 7842_2
# 7842_3
# 7842_4
# 7842_5
# 8007_1
# 8007_2
# 8007_3
# 8007_4
# 8007_5
# 8469_1
# 8469_2
# 8469_3
# 8469_4
# 8469_5
# 8673_1
# 8673_2
# 8673_3
# 8673_4
# 8673_5
# 8695_2
# 8695_3
# 8695_4
# 8695_5
# 9472_1
# 9472_2
# 9472_3
# 9472_4
# 9472_5
# 9502_1
# 9502_2
# 9502_3
# 9502_5
# 9601_1
# 9601_2
# 9601_3
# 9601_4
# 9601_5
# 0479_1

# %%
data_frame_gaze = data_frame[data_frame.events == -2].copy()

# %%
data_frame_gaze.head()
# Out:
#     index  SubjectID  Session  SessionSubsection  timeStampDataPointEnd  \
# 2       2        479        2                  1           1.653045e+09
# 19     19        479        2                  1           1.653045e+09
# 45     45        479        2                  1           1.653045e+09
# 51     51        479        2                  1           1.653045e+09
# 55     55        479        2                  1           1.653045e+09
#
#     combinedGazeValidityBitmask  eyePositionCombinedWorld.x  \
# 2                             3                  -59.116348
# 19                            3                  -59.106937
# 45                            3                  -59.114811
# 51                            3                  -59.128338
# 55                            3                  -59.111675
#
#     eyePositionCombinedWorld.y  eyePositionCombinedWorld.z  \
# 2                     2.260123                   34.715347
# 19                    2.260705                   34.714581
# 45                    2.260359                   34.713730
# 51                    2.259566                   34.713692
# 55                    2.260061                   34.713726
#
#     eyeDirectionCombinedWorld.y  ...  combined_vel     thresh      isFix  \
# 2                      0.038935  ...      0.000000  27.130421   0.000000
# 19                     0.025481  ...      2.815348  27.130421   2.815348
# 45                     0.002027  ...      0.709226  27.130421   0.709226
# 51                    -0.063595  ...      0.836695  27.130421   0.836695
# 55                    -0.063207  ...     21.173582  27.130421  21.173582
#
#     corrected_vel  events    length   distance   avg_dist          names  \
# 2             NaN    -2.0  0.006447  62.707432  62.707432   Building_161
# 19       2.815348    -2.0  0.254944  62.709146  62.709424   Building_161
# 45       0.709226    -2.0  0.389361  56.725614  56.725701       Fence_34
# 51       0.836695    -2.0  0.066463  22.469910  22.470188  terrain_O.001
# 55      21.173582    -2.0  0.044640  21.422642  21.422655  terrain_O.001
#
#     Collider_CategoricalN
# 2                Building
# 19               Building
# 45             Background
# 51             Background
# 55             Background
#
# [5 rows x 50 columns]

# %%
data_frame.tail(200)
# Out:
#          index  SubjectID  Session  SessionSubsection  timeStampDataPointEnd  \
# 114358  114358        479        1                  3           1.652970e+09
# 114359  114359        479        1                  3           1.652970e+09
# 114360  114360        479        1                  3           1.652970e+09
# 114361  114361        479        1                  3           1.652970e+09
# 114362  114362        479        1                  3           1.652970e+09
# ...        ...        ...      ...                ...                    ...
# 114553  114553        479        1                  3           1.652970e+09
# 114554  114554        479        1                  3           1.652970e+09
# 114555  114555        479        1                  3           1.652970e+09
# 114556  114556        479        1                  3           1.652970e+09
# 114557  114557        479        1                  3           1.652970e+09
#
#         combinedGazeValidityBitmask  eyePositionCombinedWorld.x  \
# 114358                            3                  194.029144
# 114359                            3                  194.029144
# 114360                            3                  194.016617
# 114361                            3                  194.016617
# 114362                            3                  194.016617
# ...                             ...                         ...
# 114553                            3                  192.045654
# 114554                            3                  191.983978
# 114555                            3                  191.920563
# 114556                            3                  191.920563
# 114557                            3                  191.920563
#
#         eyePositionCombinedWorld.y  eyePositionCombinedWorld.z  \
# 114358                    0.963270                  112.117889
# 114359                    0.963270                  112.117416
# 114360                    0.963007                  112.117325
# 114361                    0.963007                  112.116272
# 114362                    0.963007                  112.115677
# ...                            ...                         ...
# 114553                    0.856509                  117.302483
# 114554                    0.854405                  117.395813
# 114555                    0.852232                  117.488960
# 114556                    0.852232                  117.488960
# 114557                    0.852232                  117.488960
#
#         eyeDirectionCombinedWorld.y  ...  combined_vel     thresh      isFix  \
# 114358                     0.012810  ...     15.008259  27.123903  15.008259
# 114359                     0.013783  ...     26.045621  27.123903  26.045621
# 114360                     0.015348  ...      0.000000  27.123903   0.000000
# 114361                     0.023475  ...     23.781373  27.123903  23.781373
# 114362                     0.023176  ...     24.174312  27.123903  24.174312
# ...                             ...  ...           ...        ...        ...
# 114553                    -0.070025  ...      3.100830  27.123903   3.100830
# 114554                    -0.070558  ...      1.497412  27.123903   1.497412
# 114555                    -0.069931  ...      4.626266  27.123903   4.626266
# 114556                    -0.070915  ...      0.000000  27.123903   0.000000
# 114557                    -0.072977  ...      0.000000  27.123903   0.000000
#
#         corrected_vel  events    length   distance   avg_dist  \
# 114358      15.008259     NaN  0.188480  30.379239  30.387788
# 114359      26.045621     NaN  0.188480  30.379362  30.387788
# 114360       0.000000     NaN  0.188480  30.391487  30.387788
# 114361      23.781373     NaN  0.188480  30.391760  30.387788
# 114362      24.174312     NaN  0.188480  30.391914  30.387788
# ...               ...     ...       ...        ...        ...
# 114553       3.100830     NaN  0.377951  30.246194  30.759764
# 114554       1.497412     NaN  0.377951  30.134844  30.759764
# 114555       4.626266     NaN  0.377951  30.022820  30.759764
# 114556       0.000000     NaN  0.377951  30.022820  30.759764
# 114557       0.000000    -2.0  0.377951  30.022820  30.759764
#
#                    names  Collider_CategoricalN
# 114358   TaskBuilding_14    TaskBuilding_Public
# 114359   TaskBuilding_14    TaskBuilding_Public
# 114360   TaskBuilding_14    TaskBuilding_Public
# 114361   TaskBuilding_14    TaskBuilding_Public
# 114362   TaskBuilding_14    TaskBuilding_Public
# ...                  ...                    ...
# 114553  pavement_Ua6.001             Background
# 114554  pavement_Ua6.001             Background
# 114555  pavement_Ua6.001             Background
# 114556  pavement_Ua6.001             Background
# 114557  pavement_Ua6.001             Background
#
# [200 rows x 50 columns]

# %%
data_frame.iloc[114348:114378,[21,34]]
# Out:
#        hitObjectColliderName Interpolated_collider
# 114348   road_playground.002   road_playground.002
# 114349         terrain_I.001         terrain_I.001
# 114350         terrain_I.001         terrain_I.001
# 114351         terrain_I.001         terrain_I.001
# 114352         terrain_I.001         terrain_I.001
# 114353   road_playground.002   road_playground.002
# 114354         terrain_I.001         terrain_I.001
# 114355         terrain_I.001         terrain_I.001
# 114356         terrain_I.001         terrain_I.001
# 114357         terrain_I.001         terrain_I.001
# 114358         terrain_I.001         terrain_I.001
# 114359         terrain_I.001         terrain_I.001
# 114360    Complete_fence.004    Complete_fence.004
# 114361         terrain_I.001         terrain_I.001
# 114362    Complete_fence.004    Complete_fence.004
# 114363    Complete_fence.004    Complete_fence.004
# 114364    Complete_fence.004    Complete_fence.004
# 114365    Complete_fence.004    Complete_fence.004
# 114366    Complete_fence.004    Complete_fence.004
# 114367    Complete_fence.004    Complete_fence.004
# 114368    Complete_fence.004    Complete_fence.004
# 114369    Complete_fence.004    Complete_fence.004
# 114370    Complete_fence.004    Complete_fence.004
# 114371    Complete_fence.004    Complete_fence.004
# 114372    Complete_fence.004    Complete_fence.004
# 114373    Complete_fence.004    Complete_fence.004
# 114374    Complete_fence.004    Complete_fence.004
# 114375    Complete_fence.004    Complete_fence.004
# 114376    Complete_fence.004    Complete_fence.004
# 114377    Complete_fence.004    Complete_fence.004

# %%
data_frame.combinedGazeValidityBitmask.value_counts()
# Out:
# 3    13240677
# 0      836959
# Name: combinedGazeValidityBitmask, dtype: int64

# %%
Blinks = pd.DataFrame(data_frame.groupby(["SubjectID", "Session"])["combinedGazeValidityBitmask"].value_counts(normalize=True))
Blinks.rename(columns ={"combinedGazeValidityBitmask": "Percentage"}, inplace=True)
Blinks.reset_index(inplace=True)
Blinks.loc[:, 'Validity'] = Blinks['combinedGazeValidityBitmask'].replace( {3:"Valid", 0:"Invalid"})

# %%
Blinks.head()
# Out:
#    SubjectID  Session  combinedGazeValidityBitmask  Percentage Validity
# 0        479        1                            3    0.966297    Valid
# 1        479        1                            0    0.033703  Invalid
# 2        479        2                            3    0.963621    Valid
# 3        479        2                            0    0.036379  Invalid
# 4        479        3                            3    0.934566    Valid

# %%
sns.catplot(data=Blinks, hue="Validity", y="Percentage", x="SubjectID", kind="bar", \
            height=7, aspect=4).set(title="Percentage of invalid data points per subject")

# %%
data_frame.Continuous_Time.describe()
# Out:
# count    1.407764e+07
# mean     1.649533e-02
# std      1.390423e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.700000e-02
# 75%      3.300000e-02
# max      5.000000e-02
# Name: Continuous_Time, dtype: float64

# %%
data_frame_gaze["Median_Standard_Duration"] = np.nanmedian(abs(data_frame_gaze.length - np.nanmedian(data_frame_gaze.length))) * 1.4826
data_frame_gaze["gaze_mad_z"] = abs(data_frame_gaze.length.tolist() - np.nanmedian(data_frame_gaze.length)) / data_frame_gaze.Median_Standard_Duration.tolist()
data_frame_gaze["Outlier_Gaze_Length"] = np.where(data_frame_gaze["gaze_mad_z"] > 3.5, "Out", "Stays")
data_frame_gaze_no_out = data_frame_gaze[data_frame_gaze.Outlier_Gaze_Length != "OUT"]

# %%
data_frame_gaze.Outlier_Gaze_Length.value_counts(normalize=True)
# Out:
# Stays    0.949343
# Out      0.050657
# Name: Outlier_Gaze_Length, dtype: float64

# %%
data_frame_gaze.shape
# Out:
# (721643, 53)

# %%
data_frame_gaze_no_out.shape

# %%
data_frame_gaze_no_out.head()
# Out:
#     index  SubjectID  Session  SessionSubsection  timeStampDataPointEnd  \
# 2       2        479        2                  1           1.653045e+09
# 19     19        479        2                  1           1.653045e+09
# 45     45        479        2                  1           1.653045e+09
# 51     51        479        2                  1           1.653045e+09
# 55     55        479        2                  1           1.653045e+09
#
#     combinedGazeValidityBitmask  eyePositionCombinedWorld.x  \
# 2                             3                  -59.116348
# 19                            3                  -59.106937
# 45                            3                  -59.114811
# 51                            3                  -59.128338
# 55                            3                  -59.111675
#
#     eyePositionCombinedWorld.y  eyePositionCombinedWorld.z  \
# 2                     2.260123                   34.715347
# 19                    2.260705                   34.714581
# 45                    2.260359                   34.713730
# 51                    2.259566                   34.713692
# 55                    2.260061                   34.713726
#
#     eyeDirectionCombinedWorld.y  ...  corrected_vel  events    length  \
# 2                      0.038935  ...            NaN    -2.0  0.006447
# 19                     0.025481  ...       2.815348    -2.0  0.254944
# 45                     0.002027  ...       0.709226    -2.0  0.389361
# 51                    -0.063595  ...       0.836695    -2.0  0.066463
# 55                    -0.063207  ...      21.173582    -2.0  0.044640
#
#      distance   avg_dist          names  Collider_CategoricalN  \
# 2   62.707432  62.707432   Building_161               Building
# 19  62.709146  62.709424   Building_161               Building
# 45  56.725614  56.725701       Fence_34             Background
# 51  22.469910  22.470188  terrain_O.001             Background
# 55  21.422642  21.422655  terrain_O.001             Background
#
#     Median_Standard_Duration  gaze_mad_z  Outlier_Gaze_Length
# 2                   0.116925    1.272624                Stays
# 19                  0.116925    0.852645                Stays
# 45                  0.116925    2.002250                Stays
# 51                  0.116925    0.759341                Stays
# 55                  0.116925    0.945982                Stays
#
# [5 rows x 53 columns]

# %%
data_frame_gaze_no_out_ONLY_TEST = data_frame_gaze_no_out[(data_frame_gaze_no_out.Collider_CategoricalN != "Background") & (data_frame_gaze_no_out.Collider_CategoricalN != "Building")].copy()

# %%
data_frame_gaze_no_out.Collider_CategoricalN.unique()
# Out:
# array(['Building', 'Background', 'TaskBuilding_Public', 'Passive_Agent',
#        'TaskBuilding_Residential', 'Passive_Agent_Face',
#        'Global_Landmark', 'Active_Agent', 'Active_Agent_Face'],
#       dtype=object)

# %%
data_frame_gaze_no_out_ONLY_TEST.shape
# Out:
# (114753, 53)

# %%
data_frame_gaze_no_out.shape
# Out:
# (721643, 53)

# %%
patterns = {'01_Cma':1}
patterns.update(dict.fromkeys(['TaskBuilding_14'], 1))
patterns.update(dict.fromkeys(['02_Cma','TaskBuilding_41','Graffity_41'], 2))
patterns.update(dict.fromkeys(['03_Cma','TaskBuilding_2', 'Graffity_02'], 3))
patterns.update(dict.fromkeys(['04_Cma','TaskBuilding_47','Graffity_47'], 4))
patterns.update(dict.fromkeys(['05_Cma','Construction_57'], 5))
patterns.update(dict.fromkeys(['06_Cma','TaskBuilding_20','Graffity_20'], 6))
patterns.update(dict.fromkeys(['07_Cma','TaskBuilding_9','Graffity_9'], 7))
patterns.update(dict.fromkeys(['08_Cma','TaskBuilding_50','Graffity_50'], 8))
patterns.update(dict.fromkeys(['09_Cma','TaskBuilding_45','Graffity_45'], 9))
patterns.update(dict.fromkeys(['10_Cma','TaskBuilding_8','Graffity_10'], 10))
patterns.update(dict.fromkeys(['11_Cma','TaskBuilding_27','Graffity_27'], 11))
patterns.update(dict.fromkeys(['12_Cma','TaskBuilding_51','Graffity_51'], 12))
patterns.update(dict.fromkeys(['13_Cma','TaskBuilding_3','Graffity_03'], 13))
patterns.update(dict.fromkeys(['14_Cma','TaskBuilding_11','Graffity_11'], 14))
patterns.update(dict.fromkeys(['15_Cma','TaskBuilding_42','Graffity_42'], 15))
patterns.update(dict.fromkeys(['16_Cma','TaskBuilding_23','Graffity_23'], 16))
patterns.update(dict.fromkeys(['17_Cma','TaskBuilding_52','Graffity_52'], 17))
patterns.update(dict.fromkeys(['18_Cma','TaskBuilding_38','Graffity_38'], 18))
patterns.update(dict.fromkeys(['19_Cma','TaskBuilding_34','Graffity_34'], 19))
patterns.update(dict.fromkeys(['20_Cma','BasketballCourt_58'], 20))
patterns.update(dict.fromkeys(['21_Cma','TaskBuilding_5','Graffity_05'], 21))
patterns.update(dict.fromkeys(['22_Cma','TaskBuilding_29','Graffity_29'], 22))
patterns.update(dict.fromkeys(['23_Cma','TaskBuilding_32','Graffity_32'], 23))
patterns.update(dict.fromkeys(['24_Cma','TaskBuilding_13','Graffity_13'], 24))
patterns.update(dict.fromkeys(['25_Cma','TaskBuilding_44','Graffity_44'], 25))
patterns.update(dict.fromkeys(['26_Cma','TaskBuilding_21','Graffity_21'], 26))
patterns.update(dict.fromkeys(['27_Cma','TaskBuilding_59','Graffity_04'], 27))
patterns.update(dict.fromkeys(['28_Cma','Church-TaskBuilding_16'], 28))
patterns.update(dict.fromkeys(['29_Sa','TaskBuilding_4','Graffity_59'], 29))
patterns.update(dict.fromkeys(['30_Sa','TaskBuilding_1'], 30))
patterns.update(dict.fromkeys(['31_Sa','TaskBuilding_6'], 31))
patterns.update(dict.fromkeys(['32_Sa','TaskBuilding_7'], 32))
patterns.update(dict.fromkeys(['33_Sa','TaskBuilding_17'], 33))
patterns.update(dict.fromkeys(['33_Sa','TaskBuilding_17'], 33))

# %%
data_frame_gaze_no_out_ONLY_TEST

# %%
data_frame_gaze_no_out.Collider_CategoricalN.value_counts()
# Out:
# Background                  437031
# Building                    169859
# TaskBuilding_Public          60435
# TaskBuilding_Residential     27373
# Active_Agent                  8884
# Global_Landmark               8738
# Passive_Agent                 6672
# Passive_Agent_Face            1331
# Active_Agent_Face             1320
# Name: Collider_CategoricalN, dtype: int64

# %%
summary_name_stats_fix_length_NS = pd.DataFrame(data_frame_gaze_no_out_ONLY_TEST.groupby([ "SubjectID",  "names"])["length"].agg(['count','mean','median','std','max', 'min']))

# %%
HumanA = pd.read_csv("/Users/tracysanchezpacheco/Documents/Resources/humanA_Behavioural.csv")

# %%
HumanA.head()
# Out:
#    Unnamed: 0      ID  Alter   Global  Overview  Cardinal  \
# 0           0   365.0    37.0     5.6  6.285714       2.5
# 1           1  3572.0    23.0     5.7  3.142857       1.0
# 2           2  3572.0    23.0     5.7  3.142857       1.0
# 3           3  3572.0    23.0     5.7  3.142857       1.0
# 4           4  3572.0    23.0     5.7  3.142857       1.0
#
#    AffiliativeQ_average  item3  ContextQ_average  remember_action_likert  ...  \
# 0                   5.2    2.0               3.5                2.714286  ...
# 1                   4.0    2.0               4.5                2.250000  ...
# 2                   4.0    2.0               4.5                2.250000  ...
# 3                   4.0    2.0               4.5                2.250000  ...
# 4                   4.0    2.0               4.5                2.250000  ...
#
#    DistanceToParticipant  PointingTaskStartingLocations  TrialNumber  \
# 0                    NaN                            NaN          NaN
# 1             263.186127                           18.0         19.0
# 2             297.913635                            7.0        274.0
# 3             173.046249                           22.0        282.0
# 4             228.597382                           12.0        293.0
#
#    StartPointID  ID_for_StartingPosition  avatarID  AvatarPresenceCategory  \
# 0           NaN                      NaN       NaN                     NaN
# 1           2.0                      7.0       5.0                 Omitted
# 2          23.0                     10.0       5.0                 Present
# 3          24.0                      6.0       5.0                 Present
# 4          25.0                      5.0       5.0                 Present
#
#    Context  meaningfulBuilding  ImageName
# 0      NaN                 NaN        NaN
# 1     True          Meaningful   05_CmANo
# 2     True          Meaningful     05_CmA
# 3     True          Meaningful     05_CmA
# 4     True          Meaningful     05_CmA
#
# [5 rows x 29 columns]

# %%
HumanA.avatarID.unique()
# Out:
# array([nan,  5., 23.,  8., 40., 26., 21., 53., 49., 27., 48., 29.,  2.,
#        35., 41., 10.,  3., 52., 32.,  9., 15., 44., 16., 39., 51., 13.,
#         4., 56., 30., 47., 45., 55., 43., 25.,  6., 33., 50., 20., 38.,
#        14.,  1., 34., 37., 46., 42., 19., 17.,  7., 22., 28., 24., 12.,
#        31., 11., 18., 54., 36.])

# %%
summary_name_stats_fix_length_NS.reset_index(inplace=True)

# %%
summary_name_stats_fix_length_NS.names.unique()
# Out:
# array(['01_Cma', '02_Cma', '03_Cma', '05_Cma', '06_Cma', '07_Cma',
#        '08_Cma', '09_Cma', '10_Cma', '11_Cma', '12_Cma', '13_Cma',
#        '14_Cma', '15_Cma', '16_Cma', '17_Cma', '18_Cma', '19_Cma',
#        '20_Cma', '21_Cma', '22_Cma', '23_Cma', '24_Cma', '25_Cma',
#        '26_Cma', '27_Cma', '28_Cma', '29_Sa', '30_Sa', '31_Sa', '32_Sa',
#        '33_Sa', '34_Sa', '35_Sa', '36_Sa', '37_Sa', '38_Sa', '39_Sa',
#        '40_Sa', '41_Sa', '42_Sa', '43_Sa', '44_Sa', '45_Sa', '46_Sa',
#        '47_Sa', '48_Sa', '49_Sa', '50_Sa', '51_Sa', '52_Sa', '54_Sa',
#        '55_Sa', '56_Sa', 'BasketballCourt_58', 'Castle-TaskBuilding_56',
#        'Construction_57', 'Graffity_02', 'Graffity_03', 'Graffity_05',
#        'Graffity_08', 'Graffity_09', 'Graffity_11', 'Graffity_12',
#        'Graffity_13', 'Graffity_14', 'Graffity_15', 'Graffity_17',
#        'Graffity_18', 'Graffity_19', 'Graffity_20', 'Graffity_21',
#        'Graffity_22', 'Graffity_23', 'Graffity_24', 'Graffity_25',
#        'Graffity_26', 'Graffity_27', 'Graffity_28', 'Graffity_29',
#        'Graffity_30', 'Graffity_31', 'Graffity_32', 'Graffity_33',
#        'Graffity_34', 'Graffity_35', 'Graffity_36', 'Graffity_37',
#        'Graffity_38', 'Graffity_39', 'Graffity_40', 'Graffity_41',
#        'Graffity_42', 'Graffity_43', 'Graffity_44', 'Graffity_45',
#        'Graffity_46', 'Graffity_47', 'Graffity_48', 'Graffity_50',
#        'Graffity_51', 'Graffity_52', 'Graffity_55',
#        'HighSilo-TaskBuilding_49', 'TaskBuilding_1', 'TaskBuilding_11',
#        'TaskBuilding_12', 'TaskBuilding_13', 'TaskBuilding_14',
#        'TaskBuilding_15', 'TaskBuilding_17', 'TaskBuilding_18',
#        'TaskBuilding_19', 'TaskBuilding_2', 'TaskBuilding_20',
#        'TaskBuilding_21', 'TaskBuilding_22', 'TaskBuilding_23',
#        'TaskBuilding_24', 'TaskBuilding_25', 'TaskBuilding_26',
#        'TaskBuilding_27', 'TaskBuilding_28', 'TaskBuilding_29',
#        'TaskBuilding_3', 'TaskBuilding_30', 'TaskBuilding_31',
#        'TaskBuilding_32', 'TaskBuilding_33', 'TaskBuilding_34',
#        'TaskBuilding_35', 'TaskBuilding_36', 'TaskBuilding_37',
#        'TaskBuilding_38', 'TaskBuilding_39', 'TaskBuilding_4',
#        'TaskBuilding_40', 'TaskBuilding_41', 'TaskBuilding_42',
#        'TaskBuilding_43', 'TaskBuilding_44', 'TaskBuilding_45',
#        'TaskBuilding_46', 'TaskBuilding_47', 'TaskBuilding_48',
#        'TaskBuilding_5', 'TaskBuilding_50', 'TaskBuilding_51',
#        'TaskBuilding_52', 'TaskBuilding_53', 'TaskBuilding_54',
#        'TaskBuilding_55', 'TaskBuilding_6', 'TaskBuilding_7',
#        'TaskBuilding_8', 'TaskBuilding_9', 'Windmill-TaskBuilding_10_1',
#        '53_Sa', 'Graffity_54', '04_Cma'], dtype=object)

# %%
summary_name_stats_fix_length.to_csv("/Volumes/SSD/00_Data_Processing/Pre_processed/Complete_Data_AngularV_GROUPED.cvs")

# %%
summary_name_stats_fix_length.shape
# Out:
# (64656, 10)

# %%
sns.displot(data=data_frame_gaze, x="length", hue="Collider_CategoricalN", multiple="stack")
# Out:
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-20-d22450ad7a5a>", line 1, in <module>
#     sns.displot(data=data_frame_gaze, x="length", hue="Collider_CategoricalN", multiple="stack")
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py", line 2227, in displot
#     p.plot_univariate_histogram(**hist_kws)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py", line 555, in plot_univariate_histogram
#     artists = plot_func(
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 1433, in inner
#     return func(ax, *map(sanitize_sequence, args), **kwargs)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py", line 2474, in bar
#     self.add_patch(r)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 2408, in add_patch
#     self._update_patch_limits(p)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 2430, in _update_patch_limits
#     for curve, code in p.iter_bezier(simplify=False):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/matplotlib/path.py", line 452, in iter_bezier
#     yield BezierSegment(np.array([prev_vert, verts])), code
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 720, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3437, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-20-d22450ad7a5a>", line 1, in <module>
#     sns.displot(data=data_frame_gaze, x="length", hue="Collider_CategoricalN", multiple="stack")
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py", line 2227, in displot
#     p.plot_univariate_histogram(**hist_kws)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py", line 555, in plot_univariate_histogram
#     artists = plot_func(
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py", line 1433, in inner
#     return func(ax, *map(sanitize_sequence, args), **kwargs)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py", line 2474, in bar
#     self.add_patch(r)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 2408, in add_patch
#     self._update_patch_limits(p)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py", line 2430, in _update_patch_limits
#     for curve, code in p.iter_bezier(simplify=False):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/matplotlib/path.py", line 452, in iter_bezier
#     yield BezierSegment(np.array([prev_vert, verts])), code
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3357, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3454, in run_code
#     self.showtraceback(running_compiled_code=True)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2063, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(etype,
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1367, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1267, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1124, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1082, in format_exception_as_a_whole
#     last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 382, in find_recursion
#     return len(records), 0
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2061, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1101, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 248, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 281, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 1515, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 1473, in getframeinfo
#     filename = getsourcefile(frame) or getfile(frame)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 751, in getmodule
#     f = getabsfile(module)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 720, in getabsfile
#     _filename = getsourcefile(object) or getfile(object)
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/inspect.py", line 705, in getsourcefile
#     if os.path.exists(filename):
#   File "/Users/tracysanchezpacheco/opt/anaconda3/lib/python3.8/genericpath.py", line 19, in exists
#     os.stat(path)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-20-d22450ad7a5a> in <module>
# ----> 1 sns.displot(data=data_frame_gaze, x="length", hue="Collider_CategoricalN", multiple="stack")
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in displot(data, x, y, hue, row, col, weights, kind, rug, rug_kws, log_scale, legend, palette, hue_order, hue_norm, color, col_wrap, row_order, col_order, height, aspect, facet_kws, **kwargs)
#    2226             _assign_default_kwargs(hist_kws, p.plot_univariate_histogram, histplot)
# -> 2227             p.plot_univariate_histogram(**hist_kws)
#    2228
#
# ~/opt/anaconda3/lib/python3.8/site-packages/seaborn/distributions.py in plot_univariate_histogram(self, multiple, element, fill, common_norm, common_bins, shrink, kde, kde_kws, color, legend, line_kws, estimate_kws, **plot_kws)
#     554                 move = .5 * (1 - shrink)
# --> 555                 artists = plot_func(
#     556                     hist["edges"] + move,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/__init__.py in inner(ax, data, *args, **kwargs)
#    1432         if data is None:
# -> 1433             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1434
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_axes.py in bar(self, x, height, width, bottom, align, **kwargs)
#    2473                 r.sticky_edges.x.append(l)
# -> 2474             self.add_patch(r)
#    2475             patches.append(r)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in add_patch(self, p)
#    2407             p.set_clip_path(self.patch)
# -> 2408         self._update_patch_limits(p)
#    2409         self._children.append(p)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in _update_patch_limits(self, patch)
#    2429         vertices = []
# -> 2430         for curve, code in p.iter_bezier(simplify=False):
#    2431             # Get distance along the curve of any extrema
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/path.py in iter_bezier(self, **kwargs)
#     451             elif code == Path.LINETO:  # "CURVE2"
# --> 452                 yield BezierSegment(np.array([prev_vert, verts])), code
#     453             elif code == Path.CURVE3:
#
# KeyboardInterrupt:
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'KeyboardInterrupt' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3356                         asy = compare(code)
# -> 3357                     if (await self.run_code(code, result,  async_=asy)):
#    3358                         return True
#
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1123
# -> 1124         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1125                                                                tb_offset)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#
# TypeError: object of type 'NoneType' has no len()
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2060                         # in the engines. This should return a list of strings.
# -> 2061                         stb = value._render_traceback_()
#    2062                     except Exception:
#
# AttributeError: 'TypeError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/async_helpers.py in _pseudo_sync_runner(coro)
#      66     """
#      67     try:
# ---> 68         coro.send(None)
#      69     except StopIteration as exc:
#      70         return exc.value
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_cell_async(self, raw_cell, store_history, silent, shell_futures, transformed_cell, preprocessing_exc_tuple)
#    3163                     interactivity = 'async'
#    3164
# -> 3165                 has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    3166                        interactivity=interactivity, compiler=compiler, result=result)
#    3167
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in run_ast_nodes(self, nodelist, cell_name, interactivity, compiler, result)
#    3374             if result:
#    3375                 result.error_before_exec = sys.exc_info()[1]
# -> 3376             self.showtraceback()
#    3377             return True
#    3378
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2061                         stb = value._render_traceback_()
#    2062                     except Exception:
# -> 2063                         stb = self.InteractiveTB.structured_traceback(etype,
#    2064                                             value, tb, tb_offset=tb_offset)
#    2065
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1365         else:
#    1366             self.tb = tb
# -> 1367         return FormattedTB.structured_traceback(
#    1368             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1369
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1265         if mode in self.verbose_modes:
#    1266             # Verbose modes need a full traceback
# -> 1267             return VerboseTB.structured_traceback(
#    1268                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1269             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1140         chained_exc_ids = set()
#    1141         while evalue:
# -> 1142             formatted_exceptions += self.format_exception_as_a_whole(etype, evalue, etb, lines_of_context,
#    1143                                                                      chained_exceptions_tb_offset)
#    1144             exception = self.get_parts_of_chained_exception(evalue)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1080
#    1081
# -> 1082         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1083
#    1084         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     380     # first frame (from in to out) that looks different.
#     381     if not is_recursion_error(etype, value, records):
# --> 382         return len(records), 0
#     383
#     384     # Select filename, lineno, func_name to track frames with
#
# TypeError: object of type 'NoneType' has no len()

# %%
summary_stats_fix_length = pd.DataFrame(data_frame_gaze_no_out.groupby(["Collider_CategoricalN", "SubjectID", "Session"])["length"].agg(['count','mean','median','std','max', 'min']))
summary_stats_fix_length.reset_index(inplace=True)
# Out:
# ERROR! Session/line number was not unique in database. History logging moved to new session 1313

# %%
summary_stats_fix_length

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("deep")
sns.catplot(x="Collider_CategoricalN", y="count", hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN != "Background")&(summary_stats_fix_length.Collider_CategoricalN != "Building")], \
            height=7, aspect=4, kind='box').set(title="Number of gazes per session")
ax = sns.stripplot(x="Collider_CategoricalN", y="count",  hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN != "Background")&(summary_stats_fix_length.Collider_CategoricalN != "Building")], \
                   alpha=0.5, dodge=True,linewidth=1,edgecolor='gray')
ax.get_legend().remove()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("deep")
sns.catplot(x="Collider_CategoricalN", y="count", hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent_Face")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent_Face")], \
            height=7, aspect=4, kind='box').set(title="Number of gazes per session")
ax = sns.stripplot(x="Collider_CategoricalN", y="count",  hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent_Face")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent_Face")], \
                   alpha=0.5, dodge=True,linewidth=1,edgecolor='gray')
#plt.ylim(top=100)
ax.get_legend().remove()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("deep")
sns.catplot(x="Collider_CategoricalN", y="median", hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN != "Background")&(summary_stats_fix_length.Collider_CategoricalN != "Building")], \
            height=7, aspect=4, kind='box').set(title="Median gaze duration per session")
ax = sns.stripplot(x="Collider_CategoricalN", y="median",  hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN != "Background")&(summary_stats_fix_length.Collider_CategoricalN != "Building")], \
                   alpha=0.5, dodge=True,linewidth=1,edgecolor='gray')
plt.ylim(top=1)
ax.get_legend().remove()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("deep")
sns.catplot(x="Collider_CategoricalN", y="median", hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent_Face")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent_Face")], \
            height=7, aspect=4, kind='box').set(title="Median gaze duration per session")
ax = sns.stripplot(x="Collider_CategoricalN", y="median",  hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent_Face")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent_Face")], \
                   alpha=0.5, dodge=True,linewidth=1,edgecolor='gray')
ax.get_legend().remove()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("flare")
sns.catplot(x="Collider_CategoricalN", y="count", hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN != "Background")&(summary_stats_fix_length.Collider_CategoricalN != "Building")], \
            height=7, aspect=4, kind='box').set(title="Number of gazes per session")
ax = sns.stripplot(x="Collider_CategoricalN", y="count",  hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN != "Background")&(summary_stats_fix_length.Collider_CategoricalN != "Building")], \
                   alpha=0.5, dodge=True,linewidth=1,edgecolor='gray')
#plt.ylim(top=1)
ax.get_legend().remove()

# %%
HumanA = pd.read_csv("/Users/tracysanchezpacheco/Documents/Resources/humanA_Behavioural.csv")

# %%
HumanA.info()

# %%
data_frame.head(50)

# %%
data_frame.info()

# %%
data_frame.to_csv("/Volumes/SSD/00_Data_Processing/Pre_processed/Complete_Data_AngularV.cvs")

# %%
One_participant.columns

# %%
One_participant.drop(columns=['Unnamed: 0', 'level_0','Unnamed: 0.1', 'Unnamed: 0.1.1'], inplace=True)

# %%
One_participant.events.value_counts()

# %%
One_participant['avg_shift'] = One_participant['avg_dist'].shift(1) != One_participant['avg_dist']

# %%
data_frame.iloc[115318:115322,6:9]

# %%
data_frame.info()

# %%
One_participant.iloc[115521:115532,45:50]

# %%
One_participant.iloc[115318:115322,6]

# %%
One_participant.iloc[115322,6] - One_participant.iloc[115318,6]

# %%
One_participant.iloc[115532,6] - One_participant.iloc[115521,6]

# %%
One_participant.tail(200)

# %%
pd.set_option('display.max_rows', 500)

# %%
import pandas as pd
import numpy as np

# create example dataframe
df = pd.DataFrame({'case': [1, np.nan, np.nan, -1, np.nan, 2, np.nan, np.nan, -2, np.nan, np.nan, np.nan, 2, np.nan, -1]})

# fill NaN values with 0
df_filled = df.fillna(0)

# use boolean indexing to check if the ordering is correct within each group
mask = ((df_filled['case'] != 2) | (df_filled['case'].shift(-1).fillna(0) == -2)) & \
       ((df_filled['case'] != 1) | (df_filled['case'].shift(-1).fillna(0) == -1))

# print rows where the condition is False
print(df[~mask])

# %%
df
