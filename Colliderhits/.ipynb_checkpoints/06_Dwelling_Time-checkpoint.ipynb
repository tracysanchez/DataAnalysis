# %%
import pandas as pd
import numpy as np
import re
import glob
import math
import seaborn as sns
import matplotlib.pyplot as plt

# %%
path = "/Volumes/SSD/00_Data_Processing/Pre_processed/05_Debbies_gaze" 

  
# csv files in the path
files = glob.glob(path + "/*.csv")
  
# defining an empty list to store 
# content
data_frame = pd.DataFrame()
content = []
  
# checking all the csv files in the 
# specified path
for filename in files:
    
    # reading content of csv file
    # content.append(filename)
    One_participant = pd.read_csv(filename)
    One_participant.drop(columns=['Unnamed: 0', 'level_0','Unnamed: 0.1', 'Unnamed: 0.1.1'], inplace=True)
    print(filename[-10:-4])
    content.append(One_participant)

# converting content to data frame
data_frame = pd.concat(content)
# Out:
# 0479_2
# 0479_3
# 0479_5
# 1754_1
# 1754_2
# 1754_3
# 1754_4
# 1754_5
# 2258_1
# 2258_2
# 2258_3
# 2258_4
# 2258_5
# 2361_2
# 2361_3
# 2361_4
# 2361_5
# 2693_1
# 2693_2
# 2693_3
# 2693_4
# 2693_5
# 3246_1
# 3246_2
# 3246_3
# 3246_5
# 3310_1
# 3310_2
# 3310_3
# 3310_4
# 3310_5
# 3572_1
# 3572_2
# 3572_3
# 3572_4
# 3976_1
# 3976_2
# 3976_3
# 3976_4
# 3976_5
# 4176_1
# 4176_2
# 4176_3
# 4176_4
# 4176_5
# 4796_1
# 4796_2
# 4796_3
# 4796_4
# 4796_5
# 4917_1
# 4917_2
# 4917_3
# 4917_4
# 4917_5
# 5238_1
# 5238_2
# 5238_3
# 5238_4
# 5531_1
# 5531_3
# 5531_4
# 5531_5
# 5741_1
# 5741_2
# 5741_3
# 5741_4
# 5741_5
# 6642_1
# 6642_2
# 6642_3
# 6642_4
# 6642_5
# 7093_1
# 7093_2
# 7093_3
# 7093_4
# 7093_5
# 7264_1
# 7264_2
# 7264_3
# 7264_4
# 7264_5
# 7412_1
# 7412_2
# 7412_3
# 7412_4
# 7412_5
# 7842_1
# 7842_2
# 7842_3
# 7842_4
# 7842_5
# 8007_1
# 8007_2
# 8007_3
# 8007_4
# 8007_5
# 8469_1
# 8469_2
# 8469_3
# 8469_4
# 8469_5
# 8673_1
# 8673_2
# 8673_3
# 8673_4
# 8673_5
# 8695_2
# 8695_3
# 8695_4
# 8695_5
# 9472_1
# 9472_2
# 9472_3
# 9472_4
# 9472_5
# 9502_1
# 9502_2
# 9502_3
# 9502_5
# 9601_1
# 9601_2
# 9601_3
# 9601_4
# 9601_5
# 0479_1

# %%
data_frame_gaze = data_frame[data_frame.events == -2].copy()

# %%
data_frame_gaze.head()
# Out:
#      index  SubjectID  Session  SessionSubsection  timeStampDataPointEnd  \
# 45      45        479        2                  1           1.653045e+09
# 56      56        479        2                  1           1.653045e+09
# 67      67        479        2                  1           1.653045e+09
# 98      98        479        2                  1           1.653045e+09
# 126    126        479        2                  1           1.653045e+09
#
#      combinedGazeValidityBitmask  eyePositionCombinedWorld.x  \
# 45                             3                  -59.114811
# 56                             3                  -59.137642
# 67                             3                  -59.108757
# 98                             3                  -59.094723
# 126                            3                  -59.091881
#
#      eyePositionCombinedWorld.y  eyePositionCombinedWorld.z  \
# 45                     2.260359                   34.713730
# 56                     2.259124                   34.713810
# 67                     2.260679                   34.714069
# 98                     2.262995                   34.713947
# 126                    2.262978                   34.720425
#
#      eyeDirectionCombinedWorld.y  ...  combined_vel     thresh      isFix  \
# 45                      0.002027  ...     12.421627  74.106757  12.421627
# 56                      0.004807  ...     72.530481  74.106757  72.530481
# 67                      0.032885  ...      2.536672  74.106757   2.536672
# 98                     -0.009913  ...     22.032337  74.106757  22.032337
# 126                     0.156333  ...     34.761886  74.106757  34.761886
#
#      corrected_vel  events    length   distance   avg_dist          names  \
# 45       12.421627    -2.0  0.729616  62.769032  62.769032   Building_161
# 56       72.530481    -2.0  0.154255  21.692028  21.692028  terrain_O.001
# 67        2.536672    -2.0  0.166655  49.024159  49.024159   Building_162
# 98       22.032337    -2.0  0.411680  56.640754  56.640754       Fence_34
# 126      34.761886    -2.0  0.343728  64.451312  64.451312   Building_161
#
#      Collider_CategoricalN
# 45                Building
# 56              Background
# 67                Building
# 98              Background
# 126               Building
#
# [5 rows x 49 columns]

# %%
data_frame.tail(200)
# Out:
#          index  SubjectID  Session  SessionSubsection  timeStampDataPointEnd  \
# 114358  114358        479        1                  3           1.652970e+09
# 114359  114359        479        1                  3           1.652970e+09
# 114360  114360        479        1                  3           1.652970e+09
# 114361  114361        479        1                  3           1.652970e+09
# 114362  114362        479        1                  3           1.652970e+09
# ...        ...        ...      ...                ...                    ...
# 114553  114553        479        1                  3           1.652970e+09
# 114554  114554        479        1                  3           1.652970e+09
# 114555  114555        479        1                  3           1.652970e+09
# 114556  114556        479        1                  3           1.652970e+09
# 114557  114557        479        1                  3           1.652970e+09
#
#         combinedGazeValidityBitmask  eyePositionCombinedWorld.x  \
# 114358                            3                  194.029144
# 114359                            3                  194.029587
# 114360                            3                  194.014359
# 114361                            3                  194.014725
# 114362                            3                  194.016617
# ...                             ...                         ...
# 114553                            3                  192.045654
# 114554                            3                  191.983978
# 114555                            3                  191.920563
# 114556                            3                  191.885880
# 114557                            3                  191.818481
#
#         eyePositionCombinedWorld.y  eyePositionCombinedWorld.z  \
# 114358                    0.963270                  112.117889
# 114359                    0.963335                  112.117416
# 114360                    0.962926                  112.117325
# 114361                    0.962976                  112.116272
# 114362                    0.963007                  112.115677
# ...                            ...                         ...
# 114553                    0.856509                  117.302483
# 114554                    0.854405                  117.395813
# 114555                    0.852232                  117.488960
# 114556                    0.851057                  117.535599
# 114557                    0.848831                  117.627296
#
#         eyeDirectionCombinedWorld.y  ...  combined_vel     thresh      isFix  \
# 114358                     0.012810  ...    114.240940  88.953345        NaN
# 114359                     0.013783  ...     40.034954  88.953345  40.034954
# 114360                     0.015348  ...     25.234250  88.953345  25.234250
# 114361                     0.023475  ...     45.368202  88.953345  45.368202
# 114362                     0.023176  ...     24.086715  88.953345  24.086715
# ...                             ...  ...           ...        ...        ...
# 114553                    -0.070025  ...      5.485483  88.953345   5.485483
# 114554                    -0.070558  ...      2.650226  88.953345   2.650226
# 114555                    -0.069931  ...      1.563231  88.953345   1.563231
# 114556                    -0.070915  ...      4.908952  88.953345   4.908952
# 114557                    -0.072977  ...      1.519345  88.953345   1.519345
#
#         corrected_vel  events    length   distance   avg_dist  \
# 114358     114.240940    -1.0  0.078367  31.058085  31.058085
# 114359      40.034954     2.0  0.177567  30.210592  30.210592
# 114360      25.234250     NaN  0.177567  30.210592  30.210592
# 114361      45.368202     NaN  0.177567  30.210592  30.210592
# 114362      24.086715     NaN  0.177567  30.210592  30.210592
# ...               ...     ...       ...        ...        ...
# 114553       5.485483     NaN  0.377951  30.086212  30.588177
# 114554       2.650226     NaN  0.377951  29.976128  30.588177
# 114555       1.563231     NaN  0.377951  29.865280  30.588177
# 114556       4.908952     NaN  0.377951  29.803810  30.588177
# 114557       1.519345    -2.0  0.377951  29.700442  30.588177
#
#                    names  Collider_CategoricalN
# 114358   TaskBuilding_14    TaskBuilding_Public
# 114359   TaskBuilding_14    TaskBuilding_Public
# 114360   TaskBuilding_14    TaskBuilding_Public
# 114361   TaskBuilding_14    TaskBuilding_Public
# 114362   TaskBuilding_14    TaskBuilding_Public
# ...                  ...                    ...
# 114553  pavement_Ua6.001             Background
# 114554  pavement_Ua6.001             Background
# 114555  pavement_Ua6.001             Background
# 114556  pavement_Ua6.001             Background
# 114557  pavement_Ua6.001             Background
#
# [200 rows x 49 columns]

# %%
data_frame.iloc[114348:114378,[21,34]]
# Out:
#        hitObjectColliderName Interpolated_collider
# 114348   road_playground.002   road_playground.002
# 114349         terrain_I.001         terrain_I.001
# 114350         terrain_I.001         terrain_I.001
# 114351         terrain_I.001         terrain_I.001
# 114352         terrain_I.001         terrain_I.001
# 114353   road_playground.002   road_playground.002
# 114354         terrain_I.001         terrain_I.001
# 114355         terrain_I.001         terrain_I.001
# 114356         terrain_I.001         terrain_I.001
# 114357         terrain_I.001         terrain_I.001
# 114358         terrain_I.001         terrain_I.001
# 114359         terrain_I.001         terrain_I.001
# 114360    Complete_fence.004    Complete_fence.004
# 114361         terrain_I.001         terrain_I.001
# 114362    Complete_fence.004    Complete_fence.004
# 114363    Complete_fence.004    Complete_fence.004
# 114364    Complete_fence.004    Complete_fence.004
# 114365    Complete_fence.004    Complete_fence.004
# 114366    Complete_fence.004    Complete_fence.004
# 114367    Complete_fence.004    Complete_fence.004
# 114368    Complete_fence.004    Complete_fence.004
# 114369    Complete_fence.004    Complete_fence.004
# 114370    Complete_fence.004    Complete_fence.004
# 114371    Complete_fence.004    Complete_fence.004
# 114372    Complete_fence.004    Complete_fence.004
# 114373    Complete_fence.004    Complete_fence.004
# 114374    Complete_fence.004    Complete_fence.004
# 114375    Complete_fence.004    Complete_fence.004
# 114376    Complete_fence.004    Complete_fence.004
# 114377    Complete_fence.004    Complete_fence.004

# %%
data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 14077636 entries, 0 to 114557
# Data columns (total 49 columns):
#  #   Column                       Dtype
# ---  ------                       -----
#  0   index                        int64
#  1   SubjectID                    int64
#  2   Session                      int64
#  3   SessionSubsection            int64
#  4   timeStampDataPointEnd        float64
#  5   combinedGazeValidityBitmask  int64
#  6   eyePositionCombinedWorld.x   float64
#  7   eyePositionCombinedWorld.y   float64
#  8   eyePositionCombinedWorld.z   float64
#  9   eyeDirectionCombinedWorld.y  float64
#  10  eyeDirectionCombinedWorld.z  float64
#  11  eyeDirectionCombinedLocal.x  float64
#  12  eyeDirectionCombinedLocal.y  float64
#  13  eyeDirectionCombinedLocal.z  float64
#  14  playerBodyPosition.x         float64
#  15  playerBodyPosition.y         float64
#  16  playerBodyPosition.z         float64
#  17  bodyTrackerRotation.x        float64
#  18  bodyTrackerRotation.y        float64
#  19  bodyTrackerRotation.z        float64
#  20  hitColliderType              object
#  21  hitObjectColliderName        object
#  22  ordinalOfHit                 float64
#  23  hitPointOnObject_x           float64
#  24  hitPointOnObject_y           float64
#  25  hitPointOnObject_z           float64
#  26  Eucledian_distance           float64
#  27  Collider_Categorical         object
#  28  Previous_Euclidean_value     float64
#  29  Collider_stays               bool
#  30  Face_Hits                    object
#  31  Continuous_Time              float64
#  32  Time_Shift                   float64
#  33  Bitmask_flag                 object
#  34  Interpolated_collider        object
#  35  Collider_shift               bool
#  36  counter                      float64
#  37  Time_of_Gaze                 float64
#  38  Gaze                         object
#  39  combined_vel                 float64
#  40  thresh                       float64
#  41  isFix                        float64
#  42  corrected_vel                float64
#  43  events                       float64
#  44  length                       float64
#  45  distance                     float64
#  46  avg_dist                     float64
#  47  names                        object
#  48  Collider_CategoricalN        object
# dtypes: bool(2), float64(33), int64(5), object(9)
# memory usage: 5.1+ GB

# %%
data_frame.combinedGazeValidityBitmask.value_counts()
# Out:
# 3    13240677
# 0      836959
# Name: combinedGazeValidityBitmask, dtype: int64

# %%
Blinks = pd.DataFrame(data_frame.groupby(["SubjectID", "Session"])["combinedGazeValidityBitmask"].value_counts(normalize=True))
Blinks.rename(columns ={"combinedGazeValidityBitmask": "Percentage"}, inplace=True)
Blinks.reset_index(inplace=True)
Blinks.loc[:, 'Validity'] = Blinks['combinedGazeValidityBitmask'].replace( {3:"Valid", 0:"Invalid"})

# %%
Blinks.head()
# Out:
#    SubjectID  Session  combinedGazeValidityBitmask  Percentage Validity
# 0        479        1                            3    0.966297    Valid
# 1        479        1                            0    0.033703  Invalid
# 2        479        2                            3    0.963621    Valid
# 3        479        2                            0    0.036379  Invalid
# 4        479        3                            3    0.934566    Valid

# %%
sns.catplot(data=Blinks, hue="Validity", y="Percentage", x="SubjectID", kind="bar", \
            height=7, aspect=4).set(title="Percentage of invalid data points per subject")

# %%
data_frame.Continuous_Time.describe()
# Out:
# count    1.407764e+07
# mean     1.649533e-02
# std      1.390423e-02
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.700000e-02
# 75%      3.300000e-02
# max      5.000000e-02
# Name: Continuous_Time, dtype: float64

# %%
data_frame_gaze["Median_Standard_Duration"] = np.nanmedian(abs(data_frame_gaze.length - np.nanmedian(data_frame_gaze.length))) * 1.4826
data_frame_gaze["gaze_mad_z"] = abs(data_frame_gaze.length.tolist() - np.nanmedian(data_frame_gaze.length)) / data_frame_gaze.Median_Standard_Duration.tolist()
data_frame_gaze.loc[data_frame_gaze.gaze_mad_z > 3.5, "Oulier_Gaze_Length"] = "OUT"
data_frame_gaze_no_out = data_frame_gaze[data_frame_gaze != "OUT"]

# %%
sns.displot(data=data_frame_gaze, x="length", hue="Collider_CategoricalN", multiple="stack")
# Out:
# Error in callback <function flush_figures at 0x7fece9a87430> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in flush_figures()
#     119         # ignore the tracking, just draw and close all figures
#     120         try:
# --> 121             return show(True)
#     122         except Exception as e:
#     123             # safely show traceback if in IPython, else raise
#
# ~/opt/anaconda3/lib/python3.8/site-packages/ipykernel/pylab/backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~/opt/anaconda3/lib/python3.8/site-packages/decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2336                 # force the figure dpi to 72), so we need to set it again here.
#    2337                 with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2338                     result = print_method(
#    2339                         filename,
#    2340                         facecolor=facecolor,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in <lambda>(*args, **kwargs)
#    2202                 "bbox_inches_restore"}
#    2203             skip = optional_kws - {*inspect.signature(meth).parameters}
# -> 2204             print_method = functools.wraps(meth)(lambda *args, **kwargs: meth(
#    2205                 *args, **{k: v for k, v in kwargs.items() if k not in skip}))
#    2206         else:  # Let third-parties do as they see fit.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/_api/deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     408                          else deprecation_addendum,
#     409                 **kwargs)
# --> 410         return func(*inner_args, **inner_kwargs)
#     411
#     412     DECORATORS[wrapper] = decorator
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     515             *metadata*, including the default 'Software' key.
#     516         """
# --> 517         self._print_pil(filename_or_obj, "png", pil_kwargs, metadata)
#     518
#     519     def print_to_buffer(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in _print_pil(self, filename_or_obj, fmt, pil_kwargs, metadata)
#     461         *pil_kwargs* and *metadata* are forwarded).
#     462         """
# --> 463         FigureCanvasAgg.draw(self)
#     464         mpl.image.imsave(
#     465             filename_or_obj, self.buffer_rgba(), format=fmt, origin="upper",
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     403              (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     404               else nullcontext()):
# --> 405             self.figure.draw(self.renderer)
#     406             # A GUI class may be need to update a window using this draw, so
#     407             # don't forget to call the superclass.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      72     @wraps(draw)
#      73     def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 74         result = draw(artist, renderer, *args, **kwargs)
#      75         if renderer._rasterizing:
#      76             renderer.stop_rasterizing()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in draw(self, renderer)
#    3080
#    3081             self.patch.draw(renderer)
# -> 3082             mimage._draw_list_compositing_images(
#    3083                 renderer, self, artists, self.suppressComposite)
#    3084
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/axes/_base.py in draw(self, renderer)
#    3098             renderer.stop_rasterizing()
#    3099
# -> 3100         mimage._draw_list_compositing_images(
#    3101             renderer, self, artists, self.figure.suppressComposite)
#    3102
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer)
#      49                 renderer.start_filter()
#      50
# ---> 51             return draw(artist, renderer)
#      52         finally:
#      53             if artist.get_agg_filter() is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/patches.py in draw(self, renderer)
#     587         tpath = transform.transform_path_non_affine(path)
#     588         affine = transform.get_affine()
# --> 589         self._draw_paths_with_artist_properties(
#     590             renderer,
#     591             [(tpath, affine,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/patches.py in _draw_paths_with_artist_properties(self, renderer, draw_path_args_list)
#     551         gc.set_dashes(*self._dash_pattern)
#     552         gc.set_capstyle(self._capstyle)
# --> 553         gc.set_joinstyle(self._joinstyle)
#     554
#     555         gc.set_antialiased(self._antialiased)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in set_joinstyle(self, js)
#     957         js : `.JoinStyle` or %(JoinStyle)s
#     958         """
# --> 959         self._joinstyle = JoinStyle(js)
#     960
#     961     def set_linewidth(self, w):
#
# ~/opt/anaconda3/lib/python3.8/enum.py in __call__(cls, value, names, module, qualname, type, start)
#     337         """
#     338         if names is None:  # simple value lookup
# --> 339             return cls.__new__(cls, value)
#     340         # otherwise, functional API: we're creating a new Enum type
#     341         return cls._create_(
#
# KeyboardInterrupt:

# %%
data_frame_gaze.head()

# %%
data_frame['fix_length'] = np.where(data_frame.isFix.isnull(), np.nan, data_frame.length)

# %%
summary_stats_fix_length = pd.DataFrame(data_frame_gaze_no_out.groupby(["Collider_CategoricalN", "SubjectID", "Session"])["length"].agg(['count','mean','median','std','max', 'min']))
summary_stats_fix_length.reset_index(inplace=True)

# %%
summary_stats_fix_length

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("deep")
sns.catplot(x="Collider_CategoricalN", y="count", hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN != "Background")&(summary_stats_fix_length.Collider_CategoricalN != "Building")], \
            height=7, aspect=4, kind='box').set(title="Number of gazes per session")
ax = sns.stripplot(x="Collider_CategoricalN", y="count",  hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN != "Background")&(summary_stats_fix_length.Collider_CategoricalN != "Building")], \
                   alpha=0.5, dodge=True,linewidth=1,edgecolor='gray')
ax.get_legend().remove()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("deep")
sns.catplot(x="Collider_CategoricalN", y="count", hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent_Face")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent_Face")], \
            height=7, aspect=4, kind='box').set(title="Number of gazes per session")
ax = sns.stripplot(x="Collider_CategoricalN", y="count",  hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent_Face")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent_Face")], \
                   alpha=0.5, dodge=True,linewidth=1,edgecolor='gray')
#plt.ylim(top=100)
ax.get_legend().remove()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("deep")
sns.catplot(x="Collider_CategoricalN", y="median", hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN != "Background")&(summary_stats_fix_length.Collider_CategoricalN != "Building")], \
            height=7, aspect=4, kind='box').set(title="Median gaze duration per session")
ax = sns.stripplot(x="Collider_CategoricalN", y="median",  hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN != "Background")&(summary_stats_fix_length.Collider_CategoricalN != "Building")], \
                   alpha=0.5, dodge=True,linewidth=1,edgecolor='gray')
plt.ylim(top=1)
ax.get_legend().remove()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("deep")
sns.catplot(x="Collider_CategoricalN", y="median", hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent_Face")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent_Face")], \
            height=7, aspect=4, kind='box').set(title="Median gaze duration per session")
ax = sns.stripplot(x="Collider_CategoricalN", y="median",  hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Active_Agent_Face")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent")|(summary_stats_fix_length.Collider_CategoricalN == "Passive_Agent_Face")], \
                   alpha=0.5, dodge=True,linewidth=1,edgecolor='gray')
ax.get_legend().remove()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.set_palette("flare")
sns.catplot(x="Collider_CategoricalN", y="count", hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN != "Background")&(summary_stats_fix_length.Collider_CategoricalN != "Building")], \
            height=7, aspect=4, kind='box').set(title="Number of gazes per session")
ax = sns.stripplot(x="Collider_CategoricalN", y="count",  hue="Session", data=summary_stats_fix_length[(summary_stats_fix_length.Collider_CategoricalN != "Background")&(summary_stats_fix_length.Collider_CategoricalN != "Building")], \
                   alpha=0.5, dodge=True,linewidth=1,edgecolor='gray')
#plt.ylim(top=1)
ax.get_legend().remove()

# %%
HumanA = pd.read_csv("/Users/tracysanchezpacheco/Documents/Resources/humanA_Behavioural.csv")

# %%
HumanA.info()

# %%
data_frame.head(50)

# %%
data_frame.info()

# %%
data_frame.to_csv("/Volumes/SSD/00_Data_Processing/Pre_processed/Complete_Data_AngularV.cvs")

# %%
One_participant.columns

# %%
One_participant.drop(columns=['Unnamed: 0', 'level_0','Unnamed: 0.1', 'Unnamed: 0.1.1'], inplace=True)

# %%
One_participant.events.value_counts()

# %%
One_participant['avg_shift'] = One_participant['avg_dist'].shift(1) != One_participant['avg_dist']

# %%
data_frame.iloc[115318:115322,6:9]

# %%
data_frame.info()

# %%
One_participant.iloc[115521:115532,45:50]

# %%
One_participant.iloc[115318:115322,6]

# %%
One_participant.iloc[115322,6] - One_participant.iloc[115318,6]

# %%
One_participant.iloc[115532,6] - One_participant.iloc[115521,6]

# %%
One_participant.tail(200)

# %%
pd.set_option('display.max_rows', 500)

# %%
import pandas as pd
import numpy as np

# create example dataframe
df = pd.DataFrame({'case': [1, np.nan, np.nan, -1, np.nan, 2, np.nan, np.nan, -2, np.nan, np.nan, np.nan, 2, np.nan, -1]})

# fill NaN values with 0
df_filled = df.fillna(0)

# use boolean indexing to check if the ordering is correct within each group
mask = ((df_filled['case'] != 2) | (df_filled['case'].shift(-1).fillna(0) == -2)) & \
       ((df_filled['case'] != 1) | (df_filled['case'].shift(-1).fillna(0) == -1))

# print rows where the condition is False
print(df[~mask])

# %%
df
