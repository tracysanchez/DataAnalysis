# %%
# Added cell to set Working Directory to your location
import os
import ast
import glob
import numpy as np
import pandas as pd
import json
import time

# %%
path = "/Volumes/SSD/00_Data_Processing/Pre_processed/01_Indivuduals_Flat_smaller" 

# csv files in the path
files = glob.glob(path + "/*.csv")

for filename in files:
    temp_one_part = pd.read_csv(filename)
    # Drop unnecessary variables
    temp_one_part.drop(["0"],axis=1, inplace=True)
    # Format index column
    temp_one_part.rename(columns = {'Unnamed: 0':'index'}, inplace=True)
    temp_one_part.dropna(subset=['hitPointOnObject'], inplace=True)
    # Given the way our the files have been constructed up to now, the contents of "hitPointOnObject" are not longer read as dictionary.
    # So we go row by row turn them into string and then properly format them into dictionaries to be able to explote that data on the subsequent step.
    temp_one_part["hitPointOnObject"] = [ast.literal_eval(str(row_value)) for row_value in temp_one_part["hitPointOnObject"]]
    # Turn the dictionary values into columns
    temp_one_part = temp_one_part.join(temp_one_part['hitPointOnObject'].apply(pd.Series).add_prefix("hitPointOnObject_"))
    temp_one_part.drop(["hitPointOnObject"], axis=1, inplace= True)
    temp_one_part.to_csv("/Volumes/SSD/00_Data_Processing/Pre_processed/02_Individuals_Colliders/" + str(filename[-8:len(filename)]))
    print(str(filename) + " Done")
# Out:
# /Volumes/SSD/00_Data_Processing/Pre_processed/01_Indivuduals_Flat_smaller/3976.csv Done

# %%
temp_one_part.head()
# Out:
#    index  SubjectID  Session  SessionSubsection  timeStampDataPointStart  \
# 0      0       3976        1                  1             1.650276e+09
# 1      1       3976        1                  1             1.650276e+09
# 2      2       3976        1                  1             1.650276e+09
# 3      3       3976        1                  1             1.650276e+09
# 4      4       3976        1                  1             1.650276e+09
#
#    timeStampDataPointEnd  timeStampGetVerboseData  \
# 0           1.650276e+09             1.650276e+09
# 1           1.650276e+09             1.650276e+09
# 2           1.650276e+09             1.650276e+09
# 3           1.650276e+09             1.650276e+09
# 4           1.650276e+09             1.650276e+09
#
#    combinedGazeValidityBitmask  \
# 0                            3
# 1                            3
# 2                            3
# 3                            3
# 4                            3
#
#                              rayCastHitsCombinedEyes  \
# 0  [{'hitPointOnObject': {'x': -64.150634765625, ...
# 1  [{'hitPointOnObject': {'x': -64.150634765625, ...
# 2  [{'hitPointOnObject': {'x': -64.14236450195312...
# 3  [{'hitPointOnObject': {'x': -64.04310607910156...
# 4  [{'hitPointOnObject': {'x': -64.00872802734375...
#
#    eyePositionCombinedWorld.x  ...  bodyTrackerRotation.x  \
# 0                  -59.138748  ...               3.580663
# 1                  -59.138748  ...               3.580663
# 2                  -59.133556  ...               3.590083
# 3                  -59.131275  ...               3.649648
# 4                  -59.131336  ...               3.649648
#
#    bodyTrackerRotation.y  bodyTrackerRotation.z           hitColliderType  \
# 0             356.486908             237.198975  UnityEngine.MeshCollider
# 1             356.486908             237.198975  UnityEngine.MeshCollider
# 2             356.491394             237.229279  UnityEngine.MeshCollider
# 3             356.514679             237.244293  UnityEngine.MeshCollider
# 4             356.514679             237.244293  UnityEngine.MeshCollider
#
#                        hitObjectColliderBoundsCenter  hitObjectColliderName  \
# 0  {'x': -56.61457061767578, 'y': 11.379944801330...           Building_161
# 1  {'x': -56.61457061767578, 'y': 11.379944801330...           Building_161
# 2  {'x': -56.61457061767578, 'y': 11.379944801330...           Building_161
# 3  {'x': -56.61457061767578, 'y': 11.379944801330...           Building_161
# 4  {'x': -56.61457061767578, 'y': 11.379944801330...           Building_161
#
#    ordinalOfHit  hitPointOnObject_x  hitPointOnObject_y  hitPointOnObject_z
# 0           1.0          -64.150635            8.542360          105.320786
# 1           1.0          -64.150635            8.542360          105.320786
# 2           1.0          -64.142365            8.400432          105.313904
# 3           1.0          -64.043106            8.462435          105.367142
# 4           1.0          -64.008728            8.466766          105.340851
#
# [5 rows x 45 columns]
