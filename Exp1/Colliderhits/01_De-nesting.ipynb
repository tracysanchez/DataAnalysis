# %%
# Added cell to set Working Directory to your location
import os
import ast
import glob
import numpy as np
import pandas as pd
import json
import time

# %%
path = "/Volumes/TwoTeras/0_Experiment_1/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller" 

# csv files in the path
files = glob.glob(path + "/*.csv")

for filename in files:
    temp_one_part = pd.read_csv(filename)
    # Drop unnecessary variables
    temp_one_part.drop(["0"],axis=1, inplace=True)
    # Format index column
    temp_one_part.rename(columns = {'Unnamed: 0':'index'}, inplace=True)
    temp_one_part.dropna(subset=['hitPointOnObject'], inplace=True)
    # Given the way our the files have been constructed up to now, the contents of "hitPointOnObject" are not longer read as dictionary.
    # So we go row by row turn them into string and then properly format them into dictionaries to be able to explote that data on the subsequent step.
    temp_one_part["hitPointOnObject"] = [ast.literal_eval(str(row_value)) for row_value in temp_one_part["hitPointOnObject"]]
    # Turn the dictionary values into columns
    temp_one_part = temp_one_part.join(temp_one_part['hitPointOnObject'].apply(pd.Series).add_prefix("hitPointOnObject_"))
    temp_one_part.drop(["hitPointOnObject"], axis=1, inplace= True)
    temp_one_part.to_csv("/Volumes/TwoTeras/0_Experiment_1/Eye_Tracking/Pre_processed/02_Individuals_Colliders/" + str(filename[-8:len(filename)]))
    print(str(filename) + " Done")

# %%
take_a_look = pd.read_csv("/Volumes/TwoTeras/0_Experiment_1/Eye_Tracking/Pre_processed/01_Indivuduals_Flat_smaller/0365.csv")
take_a_look_after = pd.read_csv("/Volumes/TwoTeras/0_Experiment_1/Eye_Tracking/Pre_processed/02_Individuals_Colliders/0365.csv")

# %%
take_a_look.head()
# Out:
#    Unnamed: 0  SubjectID  Session  SessionSubsection  timeStampDataPointStart  \
# 0     1444919        365        1                  1             1.635519e+09
# 1     1444920        365        1                  1             1.635519e+09
# 2     1444921        365        1                  1             1.635519e+09
# 3     1444922        365        1                  1             1.635519e+09
# 4     1444923        365        1                  1             1.635519e+09
#
#    timeStampDataPointEnd  timeStampGetVerboseData  \
# 0           1.635519e+09             1.635519e+09
# 1           1.635519e+09             1.635519e+09
# 2           1.635519e+09             1.635519e+09
# 3           1.635519e+09             1.635519e+09
# 4           1.635519e+09             1.635519e+09
#
#    combinedGazeValidityBitmask  \
# 0                            3
# 1                            3
# 2                            3
# 3                            3
# 4                            3
#
#                              rayCastHitsCombinedEyes  \
# 0  [{'hitPointOnObject': {'x': -55.74089813232422...
# 1  [{'hitPointOnObject': {'x': -55.74089813232422...
# 2  [{'hitPointOnObject': {'x': -55.74089813232422...
# 3  [{'hitPointOnObject': {'x': -55.74089813232422...
# 4  [{'hitPointOnObject': {'x': -55.13987350463867...
#
#    eyePositionCombinedWorld.x  ...  bodyTrackerPosition.z  \
# 0                  -59.088028  ...               0.086556
# 1                  -59.088028  ...               0.086556
# 2                  -59.088028  ...               0.086556
# 3                  -59.088028  ...               0.086556
# 4                  -59.082943  ...               0.086666
#
#    bodyTrackerRotation.x  bodyTrackerRotation.y  bodyTrackerRotation.z   0  \
# 0             342.806915               4.303545              51.390457 NaN
# 1             342.806915               4.303545              51.390457 NaN
# 2             342.806915               4.303545              51.390457 NaN
# 3             342.806915               4.303545              51.390457 NaN
# 4             342.794434               4.305748              51.397770 NaN
#
#             hitColliderType  \
# 0  UnityEngine.MeshCollider
# 1  UnityEngine.MeshCollider
# 2  UnityEngine.MeshCollider
# 3  UnityEngine.MeshCollider
# 4  UnityEngine.MeshCollider
#
#                        hitObjectColliderBoundsCenter  hitObjectColliderName  \
# 0  {'x': -56.61457061767578, 'y': 11.379944801330...           Building_161
# 1  {'x': -61.46739196777344, 'y': 6.5191745758056...           Building_176
# 2  {'x': -56.61457061767578, 'y': 11.379944801330...           Building_161
# 3  {'x': -61.46739196777344, 'y': 6.5191745758056...           Building_176
# 4  {'x': -56.61457061767578, 'y': 11.379944801330...           Building_161
#
#                                     hitPointOnObject  ordinalOfHit
# 0  {'x': -55.74089813232422, 'y': 5.0041227340698...           1.0
# 1  {'x': -52.6111946105957, 'y': 7.40140867233276...           2.0
# 2  {'x': -55.74089813232422, 'y': 5.0041227340698...           1.0
# 3  {'x': -52.6111946105957, 'y': 7.40140867233276...           2.0
# 4  {'x': -55.13987350463867, 'y': 5.2315287590026...           1.0
#
# [5 rows x 44 columns]

# %%
take_a_look.columns
# Out:
# Index(['Unnamed: 0', 'SubjectID', 'Session', 'SessionSubsection',
#        'timeStampDataPointStart', 'timeStampDataPointEnd',
#        'timeStampGetVerboseData', 'combinedGazeValidityBitmask',
#        'rayCastHitsCombinedEyes', 'eyePositionCombinedWorld.x',
#        'eyePositionCombinedWorld.y', 'eyePositionCombinedWorld.z',
#        'eyeDirectionCombinedWorld.y', 'eyeDirectionCombinedWorld.z',
#        'eyeDirectionCombinedLocal.x', 'eyeDirectionCombinedLocal.y',
#        'eyeDirectionCombinedLocal.z', 'hmdPosition.x', 'hmdPosition.y',
#        'hmdPosition.z', 'hmdDirectionForward.x', 'hmdDirectionForward.y',
#        'hmdDirectionForward.z', 'hmdRotation.x', 'hmdRotation.y',
#        'hmdRotation.z', 'hmdDirectionUp.x', 'hmdDirectionUp.y',
#        'hmdDirectionUp.z', 'playerBodyPosition.x', 'playerBodyPosition.y',
#        'playerBodyPosition.z', 'bodyTrackerPosition.x',
#        'bodyTrackerPosition.y', 'bodyTrackerPosition.z',
#        'bodyTrackerRotation.x', 'bodyTrackerRotation.y',
#        'bodyTrackerRotation.z', '0', 'hitColliderType',
#        'hitObjectColliderBoundsCenter', 'hitObjectColliderName',
#        'hitPointOnObject', 'ordinalOfHit'],
#       dtype='object')

# %%
take_a_look.iloc[:, -4:]
# Out:
#                              hitObjectColliderBoundsCenter  \
# 0        {'x': -56.61457061767578, 'y': 11.379944801330...
# 1        {'x': -61.46739196777344, 'y': 6.5191745758056...
# 2        {'x': -56.61457061767578, 'y': 11.379944801330...
# 3        {'x': -61.46739196777344, 'y': 6.5191745758056...
# 4        {'x': -56.61457061767578, 'y': 11.379944801330...
# ...                                                    ...
# 1955366  {'x': -196.86029052734375, 'y': 2.985467433929...
# 1955367  {'x': -183.61624145507812, 'y': 6.732253074645...
# 1955368  {'x': -194.05535888671875, 'y': 3.255834579467...
# 1955369  {'x': -183.61624145507812, 'y': 6.732253074645...
# 1955370  {'x': -194.05535888671875, 'y': 3.255834579467...
#
#         hitObjectColliderName  \
# 0                Building_161
# 1                Building_176
# 2                Building_161
# 3                Building_176
# 4                Building_161
# ...                       ...
# 1955366                  Body
# 1955367      Lamppost_v1 (88)
# 1955368                  Body
# 1955369      Lamppost_v1 (88)
# 1955370                  Body
#
#                                           hitPointOnObject  ordinalOfHit
# 0        {'x': -55.74089813232422, 'y': 5.0041227340698...           1.0
# 1        {'x': -52.6111946105957, 'y': 7.40140867233276...           2.0
# 2        {'x': -55.74089813232422, 'y': 5.0041227340698...           1.0
# 3        {'x': -52.6111946105957, 'y': 7.40140867233276...           2.0
# 4        {'x': -55.13987350463867, 'y': 5.2315287590026...           1.0
# ...                                                    ...           ...
# 1955366  {'x': -197.16494750976562, 'y': 3.619048595428...           2.0
# 1955367  {'x': -183.48963928222656, 'y': 3.935498237609...           1.0
# 1955368  {'x': -196.3413543701172, 'y': 3.6453509330749...           2.0
# 1955369  {'x': -183.48963928222656, 'y': 3.935498237609...           1.0
# 1955370  {'x': -196.3413543701172, 'y': 3.6453509330749...           2.0
#
# [1955371 rows x 4 columns]

# %%
take_a_look[["hitObjectColliderName", "hitObjectColliderBoundsCenter", "ordinalOfHit", "rayCastHitsCombinedEyes"]].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1955371 entries, 0 to 1955370
# Data columns (total 4 columns):
#  #   Column                         Dtype
# ---  ------                         -----
#  0   hitObjectColliderName          object
#  1   hitObjectColliderBoundsCenter  object
#  2   ordinalOfHit                   float64
#  3   rayCastHitsCombinedEyes        object
# dtypes: float64(1), object(3)
# memory usage: 59.7+ MB

# %%
take_a_look_after.iloc[:, -4:]
# Out:
#          ordinalOfHit  hitPointOnObject_x  hitPointOnObject_y  \
# 0                 1.0          -55.740898            5.004123
# 1                 2.0          -52.611195            7.401409
# 2                 1.0          -55.740898            5.004123
# 3                 2.0          -52.611195            7.401409
# 4                 1.0          -55.139874            5.231529
# ...               ...                 ...                 ...
# 1914367           2.0         -197.164948            3.619049
# 1914368           1.0         -183.489639            3.935498
# 1914369           2.0         -196.341354            3.645351
# 1914370           1.0         -183.489639            3.935498
# 1914371           2.0         -196.341354            3.645351
#
#          hitPointOnObject_z
# 0                 99.235207
# 1                159.405701
# 2                 99.235207
# 3                159.405701
# 4                 99.566177
# ...                     ...
# 1914367           -5.124063
# 1914368           25.990997
# 1914369           -3.122838
# 1914370           25.990997
# 1914371           -3.122838
#
# [1914372 rows x 4 columns]

# %%
take_a_look_after.head()
# Out:
#    Unnamed: 0    index  SubjectID  Session  SessionSubsection  \
# 0           0  1444919        365        1                  1
# 1           1  1444920        365        1                  1
# 2           2  1444921        365        1                  1
# 3           3  1444922        365        1                  1
# 4           4  1444923        365        1                  1
#
#    timeStampDataPointStart  timeStampDataPointEnd  timeStampGetVerboseData  \
# 0             1.635519e+09           1.635519e+09             1.635519e+09
# 1             1.635519e+09           1.635519e+09             1.635519e+09
# 2             1.635519e+09           1.635519e+09             1.635519e+09
# 3             1.635519e+09           1.635519e+09             1.635519e+09
# 4             1.635519e+09           1.635519e+09             1.635519e+09
#
#    combinedGazeValidityBitmask  \
# 0                            3
# 1                            3
# 2                            3
# 3                            3
# 4                            3
#
#                              rayCastHitsCombinedEyes  ...  \
# 0  [{'hitPointOnObject': {'x': -55.74089813232422...  ...
# 1  [{'hitPointOnObject': {'x': -55.74089813232422...  ...
# 2  [{'hitPointOnObject': {'x': -55.74089813232422...  ...
# 3  [{'hitPointOnObject': {'x': -55.74089813232422...  ...
# 4  [{'hitPointOnObject': {'x': -55.13987350463867...  ...
#
#    bodyTrackerRotation.x  bodyTrackerRotation.y  bodyTrackerRotation.z  \
# 0             342.806915               4.303545              51.390457
# 1             342.806915               4.303545              51.390457
# 2             342.806915               4.303545              51.390457
# 3             342.806915               4.303545              51.390457
# 4             342.794434               4.305748              51.397770
#
#             hitColliderType  \
# 0  UnityEngine.MeshCollider
# 1  UnityEngine.MeshCollider
# 2  UnityEngine.MeshCollider
# 3  UnityEngine.MeshCollider
# 4  UnityEngine.MeshCollider
#
#                        hitObjectColliderBoundsCenter  hitObjectColliderName  \
# 0  {'x': -56.61457061767578, 'y': 11.379944801330...           Building_161
# 1  {'x': -61.46739196777344, 'y': 6.5191745758056...           Building_176
# 2  {'x': -56.61457061767578, 'y': 11.379944801330...           Building_161
# 3  {'x': -61.46739196777344, 'y': 6.5191745758056...           Building_176
# 4  {'x': -56.61457061767578, 'y': 11.379944801330...           Building_161
#
#    ordinalOfHit  hitPointOnObject_x  hitPointOnObject_y  hitPointOnObject_z
# 0           1.0          -55.740898            5.004123           99.235207
# 1           2.0          -52.611195            7.401409          159.405701
# 2           1.0          -55.740898            5.004123           99.235207
# 3           2.0          -52.611195            7.401409          159.405701
# 4           1.0          -55.139874            5.231529           99.566177
#
# [5 rows x 46 columns]

# %%
take_a_look[["hitObjectColliderName", "ordinalOfHit","hitObjectColliderBoundsCenter",  "rayCastHitsCombinedEyes"]]
# Out:
#         hitObjectColliderName  ordinalOfHit  \
# 0                Building_161           1.0
# 1                Building_176           2.0
# 2                Building_161           1.0
# 3                Building_176           2.0
# 4                Building_161           1.0
# ...                       ...           ...
# 1955366                  Body           2.0
# 1955367      Lamppost_v1 (88)           1.0
# 1955368                  Body           2.0
# 1955369      Lamppost_v1 (88)           1.0
# 1955370                  Body           2.0
#
#                              hitObjectColliderBoundsCenter  \
# 0        {'x': -56.61457061767578, 'y': 11.379944801330...
# 1        {'x': -61.46739196777344, 'y': 6.5191745758056...
# 2        {'x': -56.61457061767578, 'y': 11.379944801330...
# 3        {'x': -61.46739196777344, 'y': 6.5191745758056...
# 4        {'x': -56.61457061767578, 'y': 11.379944801330...
# ...                                                    ...
# 1955366  {'x': -196.86029052734375, 'y': 2.985467433929...
# 1955367  {'x': -183.61624145507812, 'y': 6.732253074645...
# 1955368  {'x': -194.05535888671875, 'y': 3.255834579467...
# 1955369  {'x': -183.61624145507812, 'y': 6.732253074645...
# 1955370  {'x': -194.05535888671875, 'y': 3.255834579467...
#
#                                    rayCastHitsCombinedEyes
# 0        [{'hitPointOnObject': {'x': -55.74089813232422...
# 1        [{'hitPointOnObject': {'x': -55.74089813232422...
# 2        [{'hitPointOnObject': {'x': -55.74089813232422...
# 3        [{'hitPointOnObject': {'x': -55.74089813232422...
# 4        [{'hitPointOnObject': {'x': -55.13987350463867...
# ...                                                    ...
# 1955366  [{'hitPointOnObject': {'x': -196.2408447265625...
# 1955367  [{'hitPointOnObject': {'x': -183.4896392822265...
# 1955368  [{'hitPointOnObject': {'x': -183.4896392822265...
# 1955369  [{'hitPointOnObject': {'x': -183.4896392822265...
# 1955370  [{'hitPointOnObject': {'x': -183.4896392822265...
#
# [1955371 rows x 4 columns]
