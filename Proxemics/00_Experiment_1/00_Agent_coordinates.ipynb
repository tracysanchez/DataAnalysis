# %%
import pandas as pd

# %%
file_path = "/Volumes/TwoTeras/Resources/AllAvatarsList_Coordinates_Exp1.json"
df = pd.read_json(file_path)

# %%
df.head()
# Out:
#                                                                 Avatar1  \
# AvatarID                                                             56
# AvatarName                                                        56_Sa
# AvatarCenterWorld     {'x': -256.66241455078125, 'y': 1.783131599426...
# AvatarPositionGlobal  {'x': -256.69671630859375, 'y': 1.100187301635...
# AvatarPositionLocal   {'x': -460.69000244140625, 'y': 5.153676509857...
#
#                                                                 Avatar2  \
# AvatarID                                                             39
# AvatarName                                                        39_Sa
# AvatarCenterWorld     {'x': 112.52890014648438, 'y': -0.863404273986...
# AvatarPositionGlobal  {'x': 112.51727294921875, 'y': -1.585489273071...
# AvatarPositionLocal   {'x': -91.47599792480469, 'y': 2.4679999351501...
#
#                                                                 Avatar3  \
# AvatarID                                                             19
# AvatarName                                                       19_Cma
# AvatarCenterWorld     {'x': -41.64469909667969, 'y': 1.6350693702697...
# AvatarPositionGlobal  {'x': -41.70672607421875, 'y': 0.8909997940063...
# AvatarPositionLocal   {'x': -245.6999969482422, 'y': 4.9444890022277...
#
#                                                                 Avatar4  \
# AvatarID                                                             55
# AvatarName                                                        55_Sa
# AvatarCenterWorld     {'x': 271.7437438964844, 'y': -2.1381783485412...
# AvatarPositionGlobal  {'x': 271.7532653808594, 'y': -2.8654892444610...
# AvatarPositionLocal   {'x': 67.76000213623047, 'y': 1.18799996376037...
#
#                                                                 Avatar5  \
# AvatarID                                                             25
# AvatarName                                                       25_Cma
# AvatarCenterWorld     {'x': -122.00990295410156, 'y': -0.81517839431...
# AvatarPositionGlobal  {'x': -122.16999816894531, 'y': -1.54248929023...
# AvatarPositionLocal   {'x': -326.16326904296875, 'y': 2.510999917984...
#
#                                                                 Avatar6  \
# AvatarID                                                             40
# AvatarName                                                        40_Sa
# AvatarCenterWorld     {'x': 97.11605072021484, 'y': -5.2564077377319...
# AvatarPositionGlobal  {'x': 97.11327362060547, 'y': -6.0630002021789...
# AvatarPositionLocal   {'x': -106.87999725341797, 'y': -2.00951099395...
#
#                                                                 Avatar7  \
# AvatarID                                                             41
# AvatarName                                                        41_Sa
# AvatarCenterWorld     {'x': 92.12863159179688, 'y': 0.21828317642211...
# AvatarPositionGlobal  {'x': 92.16326904296875, 'y': -0.4675807952880...
# AvatarPositionLocal   {'x': -111.83000183105469, 'y': 3.585908412933...
#
#                                                                 Avatar8  \
# AvatarID                                                             17
# AvatarName                                                       17_Cma
# AvatarCenterWorld     {'x': -245.8494110107422, 'y': 3.1428217887878...
# AvatarPositionGlobal  {'x': -245.8367156982422, 'y': 2.4155106544494...
# AvatarPositionLocal   {'x': -449.8299865722656, 'y': 6.4689998626708...
#
#                                                                 Avatar9  \
# AvatarID                                                             47
# AvatarName                                                        47_Sa
# AvatarCenterWorld     {'x': -56.38621520996094, 'y': -2.744596004486...
# AvatarPositionGlobal  {'x': -56.39674377441406, 'y': -3.451489210128...
# AvatarPositionLocal   {'x': -260.3900146484375, 'y': 0.6019999980926...
#
#                                                                Avatar10  ...  \
# AvatarID                                                              3  ...
# AvatarName                                                       03_Cma  ...
# AvatarCenterWorld     {'x': 201.87962341308594, 'y': -2.229652166366...  ...
# AvatarPositionGlobal  {'x': 201.78326416015625, 'y': -2.956963062286...  ...
# AvatarPositionLocal   {'x': -2.210000038146972, 'y': 1.0965261459350...  ...
#
#                                                                Avatar47  \
# AvatarID                                                             31
# AvatarName                                                        31_Sa
# AvatarCenterWorld     {'x': -166.2495880126953, 'y': 3.3030667304992...
# AvatarPositionGlobal  {'x': -166.2537384033203, 'y': 2.6265106201171...
# AvatarPositionLocal   {'x': -370.24700927734375, 'y': 6.679999828338...
#
#                                                                Avatar48  \
# AvatarID                                                             48
# AvatarName                                                        48_Sa
# AvatarCenterWorld     {'x': -39.97444152832031, 'y': -3.84716796875,...
# AvatarPositionGlobal  {'x': -40.00672912597656, 'y': -4.609972000122...
# AvatarPositionLocal   {'x': -244.0, 'y': -0.556482791900634, 'z': -4...
#
#                                                                Avatar49  \
# AvatarID                                                             10
# AvatarName                                                       10_Cma
# AvatarCenterWorld     {'x': -303.546630859375, 'y': 2.25231122970581...
# AvatarPositionGlobal  {'x': -303.78997802734375, 'y': 1.525000095367...
# AvatarPositionLocal   {'x': -507.78326416015625, 'y': 5.578489303588...
#
#                                                                Avatar50  \
# AvatarID                                                             52
# AvatarName                                                        52_Sa
# AvatarCenterWorld     {'x': -194.39772033691406, 'y': 0.590858459472...
# AvatarPositionGlobal  {'x': -194.4137420654297, 'y': -0.101489305496...
# AvatarPositionLocal   {'x': -398.4070129394531, 'y': 3.9519999027252...
#
#                                                                Avatar51  \
# AvatarID                                                              7
# AvatarName                                                       07_Cma
# AvatarCenterWorld     {'x': 371.8634948730469, 'y': -1.6173629760742...
# AvatarPositionGlobal  {'x': 371.8212890625, 'y': -2.240000009536743,...
# AvatarPositionLocal   {'x': 167.8280029296875, 'y': 1.81348919868469...
#
#                                                                Avatar52  \
# AvatarID                                                             46
# AvatarName                                                        46_Sa
# AvatarCenterWorld     {'x': -64.53507995605469, 'y': 1.6150650978088...
# AvatarPositionGlobal  {'x': -64.54673767089844, 'y': 0.8877539634704...
# AvatarPositionLocal   {'x': -268.5400085449219, 'y': 4.9412431716918...
#
#                                                                Avatar53  \
# AvatarID                                                             35
# AvatarName                                                        35_Sa
# AvatarCenterWorld     {'x': 395.5722961425781, 'y': -1.5701613426208...
# AvatarPositionGlobal  {'x': 395.56329345703125, 'y': -2.342489242553...
# AvatarPositionLocal   {'x': 191.57000732421875, 'y': 1.7109999656677...
#
#                                                                Avatar54  \
# AvatarID                                                             36
# AvatarName                                                        36_Sa
# AvatarCenterWorld     {'x': 162.0011444091797, 'y': -0.3945171833038...
# AvatarPositionGlobal  {'x': 162.0, 'y': -1.121828079223632, 'z': 133...
# AvatarPositionLocal   {'x': -41.99327087402344, 'y': 2.9316611289978...
#
#                                                                Avatar55  \
# AvatarID                                                             21
# AvatarName                                                       21_Cma
# AvatarCenterWorld     {'x': -3.969467163085937, 'y': 0.8660349845886...
# AvatarPositionGlobal  {'x': -3.96673583984375, 'y': 0.20070552825927...
# AvatarPositionLocal   {'x': -207.9600067138672, 'y': 4.2541947364807...
#
#                                                                Avatar56
# AvatarID                                                             14
# AvatarName                                                       14_Cma
# AvatarCenterWorld     {'x': 343.344970703125, 'y': -0.80668902397155...
# AvatarPositionGlobal  {'x': 343.35400390625, 'y': -1.533999919891357...
# AvatarPositionLocal   {'x': 139.36073303222656, 'y': 2.5194892883300...
#
# [5 rows x 56 columns]

# %%
# Converting nested dictionary to DataFrame by treating row labels as columns
df_T = pd.DataFrame(df).T  # Transpose to switch rows and columns

# Splitting nested dictionaries for each position type into separate columns, including the rotation variable
for col in ["AvatarCenterWorld", "AvatarPositionGlobal", "AvatarPositionLocal"]:
    df_T[[f"{col}_x", f"{col}_y", f"{col}_z"]] = df_T[col].apply(pd.Series)

# Handling the AvatarRotationGlobal column, which has x, y, z, and w
df_T[['AvatarRotationGlobal_x', 'AvatarRotationGlobal_y', 'AvatarRotationGlobal_z', 'AvatarRotationGlobal_w']] = df_T['AvatarRotationGlobal'].apply(pd.Series)

# Dropping the original dictionary columns if you no longer need them
df_T = df_T.drop(columns=["AvatarCenterWorld", "AvatarPositionGlobal", "AvatarPositionLocal", "AvatarRotationGlobal"])

# Display the DataFrame (optional)
df_T.head()
# Out:
#         AvatarID AvatarName  \
# Avatar1       56      56_Sa
# Avatar2       39      39_Sa
# Avatar3       19     19_Cma
# Avatar4       55      55_Sa
# Avatar5       25     25_Cma
#
#                                        AvatarRotationLocal  \
# Avatar1  {'x': 0.0, 'y': -0.9727782607078551, 'z': 0.0,...
# Avatar2  {'x': 0.0, 'y': 0.411333680152893, 'z': 0.0, '...
# Avatar3  {'x': 0.0, 'y': 0.5777319669723511, 'z': 0.0, ...
# Avatar4  {'x': 0.0, 'y': -0.523101925849914, 'z': 0.0, ...
# Avatar5  {'x': 0.0, 'y': 0.507645010948181, 'z': 0.0, '...
#
#                            AvatarRotationVector3Global  \
# Avatar1  {'x': 0.0, 'y': 206.79885864257812, 'z': 0.0}
# Avatar2   {'x': 0.0, 'y': 48.57728576660156, 'z': 0.0}
# Avatar3   {'x': 0.0, 'y': 70.58235931396484, 'z': 0.0}
# Avatar4  {'x': 0.0, 'y': 296.91888427734375, 'z': 0.0}
# Avatar5  {'x': 0.0, 'y': 61.014183044433594, 'z': 0.0}
#
#                             AvatarRotationVector3Local  \
# Avatar1  {'x': 0.0, 'y': 206.79885864257812, 'z': 0.0}
# Avatar2   {'x': 0.0, 'y': 48.57728576660156, 'z': 0.0}
# Avatar3   {'x': 0.0, 'y': 70.58235931396484, 'z': 0.0}
# Avatar4  {'x': 0.0, 'y': 296.91888427734375, 'z': 0.0}
# Avatar5  {'x': 0.0, 'y': 61.014183044433594, 'z': 0.0}
#
#                                           AvatarLossyScale  \
# Avatar1  {'x': 1.000000357627868, 'y': 1.0, 'z': 1.0000...
# Avatar2                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
# Avatar3  {'x': 1.000000119209289, 'y': 1.0, 'z': 1.0000...
# Avatar4  {'x': 1.000000119209289, 'y': 1.0, 'z': 1.0000...
# Avatar5                     {'x': 1.0, 'y': 1.0, 'z': 1.0}
#
#                        AvatarLocalScale  \
# Avatar1  {'x': 1.0, 'y': 1.0, 'z': 1.0}
# Avatar2  {'x': 1.0, 'y': 1.0, 'z': 1.0}
# Avatar3  {'x': 1.0, 'y': 1.0, 'z': 1.0}
# Avatar4  {'x': 1.0, 'y': 1.0, 'z': 1.0}
# Avatar5  {'x': 1.0, 'y': 1.0, 'z': 1.0}
#
#                                     AvatarForwardDirection  \
# Avatar1  {'x': -0.45085969567298806, 'y': 0.0, 'z': -0....
# Avatar2  {'x': 0.749848842620849, 'y': 0.0, 'z': 0.6616...
# Avatar3  {'x': 0.9431204199790951, 'y': 0.0, 'z': 0.332...
# Avatar4  {'x': -0.891648352146148, 'y': 0.0, 'z': 0.452...
# Avatar5  {'x': 0.8747397065162651, 'y': 0.0, 'z': 0.484...
#
#                       AvatarUpDirection  \
# Avatar1  {'x': 0.0, 'y': 1.0, 'z': 0.0}
# Avatar2  {'x': 0.0, 'y': 1.0, 'z': 0.0}
# Avatar3  {'x': 0.0, 'y': 1.0, 'z': 0.0}
# Avatar4  {'x': 0.0, 'y': 1.0, 'z': 0.0}
# Avatar5  {'x': 0.0, 'y': 1.0, 'z': 0.0}
#
#                                       AvatarRightDirection  ...  \
# Avatar1  {'x': -0.8925950527191161, 'y': 0.0, 'z': 0.45...  ...
# Avatar2  {'x': 0.661609172821044, 'y': 0.0, 'z': -0.749...  ...
# Avatar3  {'x': 0.332451522350311, 'y': 0.0, 'z': -0.943...  ...
# Avatar4  {'x': 0.45272874832153304, 'y': 0.0, 'z': 0.89...  ...
# Avatar5  {'x': 0.48459309339523304, 'y': 0.0, 'z': -0.8...  ...
#
#          AvatarPositionGlobal_x  AvatarPositionGlobal_y  \
# Avatar1             -256.696716                1.100187
# Avatar2              112.517273               -1.585489
# Avatar3              -41.706726                0.891000
# Avatar4              271.753265               -2.865489
# Avatar5             -122.169998               -1.542489
#
#          AvatarPositionGlobal_z  AvatarPositionLocal_x  AvatarPositionLocal_y  \
# Avatar1              224.165863            -460.690002               5.153677
# Avatar2               -6.309143             -91.475998               2.468000
# Avatar3              142.575867            -245.699997               4.944489
# Avatar4              191.555862              67.760002               1.188000
# Avatar5             -135.090012            -326.163269               2.511000
#
#          AvatarPositionLocal_z  AvatarRotationGlobal_x  \
# Avatar1              -9.510000                     0.0
# Avatar2            -239.985001                     0.0
# Avatar3             -91.099998                     0.0
# Avatar4             -42.119999                     0.0
# Avatar5            -368.765869                     0.0
#
#          AvatarRotationGlobal_y  AvatarRotationGlobal_z  \
# Avatar1               -0.972778                     0.0
# Avatar2                0.411334                     0.0
# Avatar3                0.577732                     0.0
# Avatar4               -0.523102                     0.0
# Avatar5                0.507645                     0.0
#
#          AvatarRotationGlobal_w
# Avatar1                0.231738
# Avatar2                0.911485
# Avatar3                0.816227
# Avatar4                0.852270
# Avatar5                0.861566
#
# [5 rows x 23 columns]

# %%
def check_consistency(df, df_T):
    no_mismatch = True  # Flag to track if any mismatches are found
    
    # Iterate over each avatar (row in the original dataframe)
    for avatar_name in df.columns:
        # Access the original nested dictionary values for the current avatar
        center_world_original = df[avatar_name]['AvatarCenterWorld']
        position_global_original = df[avatar_name]['AvatarPositionGlobal']
        position_local_original = df[avatar_name]['AvatarPositionLocal']
        rotation_global_original = df[avatar_name]['AvatarRotationGlobal']
        
        # Access the transformed values in df_T for the same avatar (row)
        center_world_transformed = {
            'x': df_T.loc[avatar_name, 'AvatarCenterWorld_x'],
            'y': df_T.loc[avatar_name, 'AvatarCenterWorld_y'],
            'z': df_T.loc[avatar_name, 'AvatarCenterWorld_z']
        }
        position_global_transformed = {
            'x': df_T.loc[avatar_name, 'AvatarPositionGlobal_x'],
            'y': df_T.loc[avatar_name, 'AvatarPositionGlobal_y'],
            'z': df_T.loc[avatar_name, 'AvatarPositionGlobal_z']
        }
        position_local_transformed = {
            'x': df_T.loc[avatar_name, 'AvatarPositionLocal_x'],
            'y': df_T.loc[avatar_name, 'AvatarPositionLocal_y'],
            'z': df_T.loc[avatar_name, 'AvatarPositionLocal_z']
        }
        rotation_global_transformed = {
            'x': df_T.loc[avatar_name, 'AvatarRotationGlobal_x'],
            'y': df_T.loc[avatar_name, 'AvatarRotationGlobal_y'],
            'z': df_T.loc[avatar_name, 'AvatarRotationGlobal_z'],
            'w': df_T.loc[avatar_name, 'AvatarRotationGlobal_w']
        }

        # Compare the values and print mismatches
        if center_world_original != center_world_transformed:
            print(f"Mismatch in AvatarCenterWorld for {avatar_name}")
            no_mismatch = False
        if position_global_original != position_global_transformed:
            print(f"Mismatch in AvatarPositionGlobal for {avatar_name}")
            no_mismatch = False
        if position_local_original != position_local_transformed:
            print(f"Mismatch in AvatarPositionLocal for {avatar_name}")
            no_mismatch = False
        if rotation_global_original != rotation_global_transformed:
            print(f"Mismatch in AvatarRotationGlobal for {avatar_name}")
            no_mismatch = False

    # If no mismatches were found, print a success message
    if no_mismatch:
        print("All values match between the original and transformed data.")

# Call the function to check consistency between the original and transformed DataFrames
check_consistency(df, df_T)
# Out:
# All values match between the original and transformed data.

# %%
# Adding 'AvatarID' and 'AvatarName' to the DataFrame along with columns that contain underscores
columns_to_keep = ['AvatarID', 'AvatarName'] + [col for col in df_T.columns if '_' in col]

# Creating the new DataFrame with the selected columns
df_filtered_with_id_name = df_T[columns_to_keep]

# Display the filtered DataFrame
df_filtered_with_id_name.head()
# Out:
#         AvatarID AvatarName  AvatarCenterWorld_x  AvatarCenterWorld_y  \
# Avatar1       56      56_Sa          -256.662415             1.783132
# Avatar2       39      39_Sa           112.528900            -0.863404
# Avatar3       19     19_Cma           -41.644699             1.635069
# Avatar4       55      55_Sa           271.743744            -2.138178
# Avatar5       25     25_Cma          -122.009903            -0.815178
#
#          AvatarCenterWorld_z  AvatarPositionGlobal_x  AvatarPositionGlobal_y  \
# Avatar1           224.148331             -256.696716                1.100187
# Avatar2            -6.322067              112.517273               -1.585489
# Avatar3           142.613770              -41.706726                0.891000
# Avatar4           191.537445              271.753265               -2.865489
# Avatar5          -135.027603             -122.169998               -1.542489
#
#          AvatarPositionGlobal_z  AvatarPositionLocal_x  AvatarPositionLocal_y  \
# Avatar1              224.165863            -460.690002               5.153677
# Avatar2               -6.309143             -91.475998               2.468000
# Avatar3              142.575867            -245.699997               4.944489
# Avatar4              191.555862              67.760002               1.188000
# Avatar5             -135.090012            -326.163269               2.511000
#
#          AvatarPositionLocal_z  AvatarRotationGlobal_x  \
# Avatar1              -9.510000                     0.0
# Avatar2            -239.985001                     0.0
# Avatar3             -91.099998                     0.0
# Avatar4             -42.119999                     0.0
# Avatar5            -368.765869                     0.0
#
#          AvatarRotationGlobal_y  AvatarRotationGlobal_z  \
# Avatar1               -0.972778                     0.0
# Avatar2                0.411334                     0.0
# Avatar3                0.577732                     0.0
# Avatar4               -0.523102                     0.0
# Avatar5                0.507645                     0.0
#
#          AvatarRotationGlobal_w
# Avatar1                0.231738
# Avatar2                0.911485
# Avatar3                0.816227
# Avatar4                0.852270
# Avatar5                0.861566

# %%
df_filtered_with_id_name.to_csv("/Volumes/TwoTeras/Resources/Agent_Coordinates_Exp1.csv",index=False)
